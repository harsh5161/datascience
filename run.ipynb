# %% [markdown]
# # Proton Training and Validation Modularized

# %% [markdown]
# ## Dependencies

# %%
# !pip3 install swifter
# !pip3 install xgboost
# !pip3 install tqdm
# !pip3 install category_encoders
# !pip3 install joblib
# !pip3 install scikit-plot
# !pip3 install catboost
# !pip3 install RegscorePy
# !pip3 install -U spacy
# !pip3 install gensim
# !pip3 install xlrd
# !pip3 install lightgbm
# !pip3 install hyperopt
# !pip3 install holidays
# !pip3 install textblob
# !pip3 install pydotplus
# !pip3 install graphviz
# !pip3 install imblearn

# Download en_core_web_sm for text analytics

# %% [markdown]
# ## Main Function

# %%
import warnings
warnings.filterwarnings('ignore')
from predictive.predictive_Training import predictive_main
from segmentation.seg_Training import seg_main
from timeseries.time_Training import time_main
def main():
    '''
    PROTON MAIN FUNCTION
    '''
    print("Please select the kind of analysis you want to perform\nEnter (1) for Predictive Analysis\nEnter (2) for Segmentation Analysis\nEnter (3) for Time Series Analysis")
    analysis_input = input("Enter a number to start analysis: Enter (1) for Predictive Analysis||Enter (2) for Segmentation Analysis||Enter (3) for Time Series Analysis")
    if analysis_input == '1':
        analysis = 'Predictive'
    elif analysis_input =='2':
        analysis = 'Segmentation'
    elif analysis_input == '3':
        analysis = 'TimeSeries'
    else:
        analysis = None 

    if analysis=='Predictive':
        _ = predictive_main()
    elif analysis=='Segmentation':
       _ = seg_main()
    elif analysis=='TimeSeries':
        _ = time_main()
    else:
        _ = None
    
    if _ == None:
        print("### UNSUPPORTED OPTION SELECTED ###")
        print("### QUITTING ###")
    else:
        print("### SELECTED OPTION EXECUTED SUCCESSFULY ###")
        print("### QUITTING ###")
    return 1

if __name__ == '__main__':
    # Main Function call
    ret = main()
# Out:
# ### Importing Package: Predictive ###
# 1/8 modules imported
# 2/8 modules imported
# 3/8 modules imported
# 4/8 modules imported
# 5/8 modules imported
# 6/8 modules imported
# 7/8 modules imported
# 8/8 modules imported
# ### Package: Predictive Imported Successfully ###
# ### Importing Package: Segmentation ###
# 1/8 modules imported
# 2/8 modules imported
# 3/8 modules imported
# 4/8 modules imported
# 5/8 modules imported
# 6/8 modules imported
# 7/8 modules imported
# 8/8 modules imported
# ### Package: Segmentation Imported Successfully ###
# ### Importing Package: Time Series ###
# 1/8 modules imported
# 2/8 modules imported
# 3/8 modules imported
# 4/8 modules imported
# 5/8 modules imported
# 6/8 modules imported
# 7/8 modules imported
# 8/8 modules imported
# ### Package: TimeSeries Imported Successfully ###
# Please select the kind of analysis you want to perform
# Enter (1) for Predictive Analysis
# Enter (2) for Segmentation Analysis
# Enter (3) for Time Series Analysis
# #### RUNNING WAIT ####
# extension is csv
# We have a csv file
# This file has 12 columns and 30 rows
#
# DataFrame Succesfully imported
#
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#
# Enter 'quit' to quit
# Target Spotted!
#
# Enter 'quit' to quit
# Key  Not found in the data
# Preview can't be shown!!
# Identification column obtained
# Do you think you have Successive Targets based on the current target? If yes, enter the column names below
# in this format separated by commas: col1,col2,col3
# No Columns removed
# Would you like to remove any other ID,zip Code,Phone Numbers,UNIQUE lists,
# Or columns that have only one unique entry? If yes, enter the column names below
# in this format separated by commas: col1,col2,col3
# No Columns removed
# QUICK MODELLING WITH DEFAULT PARAMETERS
# #### RUNNING WAIT ####
# extension is csv
# We have a csv file
# This file has 12 columns and 891 rows
# ###Performing Initial Numeric Engineering for Capping Purposes###
# 		 stripping spaces, symbols, and lower casing all entries
# done ...
# 		 Replacing empty and invalid strings
# done ...
# 		 Replacing commas if present in Currencies
# done ...
# 		 Finding Numeric Columns
# done ...
# 		   PassengerId is of type int64
# 		   Survived is of type int64
# 		   Pclass is of type int64
# 		   Name is of type object
# 		   Sex is of type object
# 		   Age is of type float64
# 		   SibSp is of type int64
# 		   Parch is of type int64
# 		   Ticket is of type float64
# 		   Fare is of type float64
# 		   Cabin is of type object
# 		   Embarked is of type object
# Numeric Engineering time taken: 0.04137396812438965
#
#
#
# ### TARGET ANALYSIS ENTERED ###
# Target has 2 unique values
# Printing % occurence of each class in target Column
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64
# Dataset has not been capped
# Length of the dataset is same as original 891
# Length of the dataframe is 891
#              Missing in %
# Cabin               77.10
# Age                 19.87
# Embarked             0.22
# PassengerId          0.00
# Survived             0.00
# Fare                 0.00
# Ticket               0.00
# Parch                0.00
# SibSp                0.00
# Sex                  0.00
#
#  ### Entering Numeric Engineering of Target###
#
# 		 stripping spaces, symbols, and lower casing all entries
# done ...
# 		 Replacing empty and invalid strings
# done ...
# 		 Replacing commas if present in Currencies
# done ...
# 		 Finding Numeric Columns
# done ...
# 		   Pclass is of type int64
# 		   Name is of type object
# 		   Sex is of type object
# 		   Age is of type float64
# 		   SibSp is of type int64
# 		   Parch is of type int64
# 		   Ticket is of type float64
# 		   Fare is of type float64
# 		   Cabin is of type object
# 		   Embarked is of type object
# 		   Survived is of type int64
# Numeric Engineering time taken: 0.0375361442565918
#
#
#
# ### TARGET ANALYSIS ENTERED ###
# Target has 2 unique values
# Printing % occurence of each class in target Column
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64
#
# Target has 2 Levels! No classes will be removed
# Survived column needs Classification
#
#  0 rows were removed since target had these missing
#
# Removing Rows and Columns with more than 50% missing
#
# Rows are getting dropped first then rows
# The columns getting dropped are ['Cabin']
# Shape of the dataframe: (712, 9)
# Shape of the target column (712,)
# After removal of highly missing rows and columns
#           Missing in %
# Ticket           25.00
# Age              19.52
# Embarked          0.28
# Fare              0.00
# Parch             0.00
# SibSp             0.00
# Sex               0.00
# Name              0.00
# Pclass            0.00
# Shape of X_train is (712, 9)
# Shape of y_train is (712,)
# printing target variable distribution for classification:
#
# 0    0.616573
# 1    0.383427
# Name: Survived, dtype: float64
#
# #### DATE ENGINEERING RUNNING WAIT ####
# Date Columns found are []
#  #### DONE ####
#
#  ### Entering Segregation Zone ###
#
#
# #### Entering Segregation ####
#
# There are 3 pure numeric columns
# There are 3 categorical numeric columns
#
# The pure numeric columns are Index(['Age', 'Ticket', 'Fare'], dtype='object')
# The categorical numeric columns are Index(['Parch', 'SibSp', 'Pclass'], dtype='object')
#
# We found 3 obj type columns!
# Printing Cardinality info of All Object Type Columns!
#
# Sex           2
# Embarked      4
# Name        712
# dtype: int64
#
#
# Sex has top 5 levels that contribute to more than 10% of data!
# Sex has 2 levels before grouping
# Sex is a discrete column!
#
# Embarked has top 5 levels that contribute to more than 10% of data!
# Embarked has 4 levels before grouping
# Embarked is a discrete column!
#
# Name has top 5 levels that contribute to less than 10% of data!
# Name is unique
#
#
# We found 1 unique columns!
#
#
# The unique columns are ['Name']
#
# We now have 2 obj type discrete columns!
#
# Printing Cardinality info of obj Discrete Columns!
#
# Sex         2
# Embarked    4
# dtype: int64
#
# ### TARGET ANALYSIS ENTERED ###
# Target has 2 unique values
# Printing % occurence of each class in target Column
# 0    0.616573
# 1    0.383427
# Name: Survived, dtype: float64
# MissForest imputation will be done...
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Time taken for the completion of MissForest is : 1.7576687335968018
#
# Printing Cardinality info of all Discrete Columns! That is categorical numerical + obj type discrete!
#
# Parch       7
# SibSp       7
# Pclass      3
# Sex         2
# Embarked    4
# dtype: int64
#
# Segregation time taken : 1.8725512027740479
# Segregation Done!
#
# #### OUTLIER WINSORIZING ####
#  #### DONE ####
# Name count of words is 0 - 0 - 56 - 60 -
# dropping column Name
# (150, 0)
# Time taken to tokenize the DataFrame 0.6959002017974854
# Columns that are going to be removed are  ['Name']
# Time taken for completion of excess column removal: 0.0007061958312988281
# No Remarks or Comments Found
# Extracting Review Columns time 0.707211971282959
# No review/comment columns found
# total text analytics time taken = 0.7083678245544434
# Text Engineering Result Empty DataFrame
# Columns: []
# Index: []
#
#  #### PEARSON CORRELATION ####
#
# 0 columns removed which were highly correlated
# The columns removed are []
#  #### DONE ####
# num_df - (712, 3)
# disc_df - (712, 5)
# DATE_DF - (0, 0)
# TEXT_DF - (0, 0)
#
#  #### TRANSFORMATIONS ####
#
#  #### TARGET ENCODING ####
# (712, 8)
# (712,)
# Target Encoding Time taken : 0.10522127151489258
#
#  #### FEATURE SELECTION ####
# (712, 8)
# runnning classifier selector
#
# Binary Classification
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# thresh2: 74.6
#
# The final score sheet of 6 selected columns with importances:
#
#   col_name  scores2   t/f
# 1   Ticket      938  True
# 0      Age      783  True
# 2     Fare      653  True
# 4    SibSp       96  True
# 6      Sex       94  True
# 5   Pclass       77  True
#
# 2 columns are eliminated during Feature Selection which are:
# {'Parch', 'Embarked'}
# (712, 8)
# (712,)
# Feature Selection Time taken : 0.7975320816040039
# R[write to console]: Loading required package: tibble
#
# Feature Selection Plot Time taken : 0.289945125579834
# (712, 6)
# (712,)
#
#  #### DECISION TREE VISUALIZATION ####
# Length of X_cart and y_cart 712 --- 712
# Length of X_cart_res and y_cart_res 878 --- 878
# Sex column will now be truncated
# The values after truncating the text are as follows
# male      516
# female    362
# Name: Sex, dtype: int64
# What you want Classification
# R[write to console]: Loading required package: bitops
#
# R[write to console]: Rattle: A free graphical interface for data science with R.
# Version 5.4.0 Copyright (c) 2006-2020 Togaware Pty Ltd.
# Type 'rattle()' to shake, rattle, and roll your data.
#
# Class weights are  [0.5 0.5]
# DISCRETE COLUMNS ARE:     Parch SibSp Pclass     Sex Embarked
# 0       0     0      3  female        q
# 1       2     4      3  female        s
# 2       0     1      3  female        s
# 3       0     0      3    male        s
# 4       2     1      1  female        s
# ..    ...   ...    ...     ...      ...
# 707     0     0      3    male        s
# 708     0     0      3    male        s
# 709     0     0      2    male        s
# 710     0     0      1  female        c
# 711     0     0      3    male        s
#
# [712 rows x 5 columns]
# DISCRETE COLUMNS ARE!!!!!!!: ['SibSp', 'Pclass', 'Sex']
# Categorical Columns considered:
#
# Index(['SibSp', 'Pclass', 'Sex'], dtype='object')
# Non-Categorical Columns considered:
#
# Index(['Age', 'Ticket', 'Fare'], dtype='object')
# value=[n1,n2,n3...] where n1,n2,n3 are the number of samples of the classes in the order
# value=[0 1]
# ['0', '1']
# (712, 6)
# (712,)
#
#  #### NORMALIZATION ####
#  #### DONE ####
# (712, 6)
# (712,)
#
#  #### POWER TRANSFORMATIONS ####
#  #### DONE ####
# (712, 6)
# (712,)
#
#  #### Printing Sample Equation of the DATA ####
# LABEL ENCODED FOR SAMPLE EQUATION
#
#
# LOGISTIC REGRESSION EQUATION:
#
#
# ln(odds) = 0.005005557200917529*Age + -2.9518090090774965e-06*Ticket + 0.015894073258817334*Fare + 9.34291713384612e-06*SibSp + 6.97285970460687e-05*Pclass + -0.0002777975429135506*Sex + 0.00020847184884731834
#
# => odds = exp ( 0.005005557200917529*Age + -2.9518090090774965e-06*Ticket + 0.015894073258817334*Fare + 9.34291713384612e-06*SibSp + 6.97285970460687e-05*Pclass + -0.0002777975429135506*Sex + 0.00020847184884731834 )
#
# Where, odds = P(class=1) / 1 - P(class=1)
#
# In simple terms Odds of an event happening is defined as the likelihood that an event will occur, expressed as a proportion of the likelihood that the event will not occur. For example - the odds of rolling four on a dice are 1/6 or 16.67%.
#
# Estimated f1 score =  63.67%
# (F1 score is the harmonic mean of precision and recall, it tells how good the model is at predicting correctly and avoiding false predictions. Simply put, it is approximate accuracy.)
#
# Where the columns are encoded like this:
#
# +--------+---------------+
# | Sex    |   Sex encoded |
# |--------+---------------|
# | female |             0 |
# | male   |             1 |
# +--------+---------------+
#  #### DONE ####
#
# This is final shape of X_train : (712, 6)
# This is final shape of Y_train : (712,)
#
#
#  #### SAVING INIT INFORMATION ####
#  #### DONE ####
#
#  TOTAL TRAINING DATA CLEANING AND PLOTS : 5.649500131607056
#
# 	 #### VALIDATION AND SCORING ZONE ####
# Value of Key from Training is:  PassengerId
# Total no. of null values present in the Key:  0
# NUll values after removal are:  0
# Pandas Apply: 100%|██████████| 3/3 [00:00<00:00, 1079.24it/s]
#
#  #### TRANSFORMATION AND PREDICTION ####
# num_df - (179, 3)
# disc_df - (179, 5)
# DATE_DF - (0, 0)
# TEXT_DF - (0, 0)
#
# This is final shape of X_test : (179, 6)
#
#  #### PRINTING THE LIST OF COLUMNS AND ITS TYPES THAT ENTER THE MODEL TRAINING ####
# #### PRINTING X_test ####
# Index(['Age', 'Ticket', 'Fare', 'SibSp', 'Pclass', 'Sex'], dtype='object')
# Age       float64
# Ticket    float64
# Fare      float64
# SibSp     float64
# Pclass    float64
# Sex       float64
# dtype: object
#
#
#          Age    Ticket      Fare     SibSp    Pclass  Sex
# 0   1.000000  0.655489  0.255895  0.571591  0.722909  0.0
# 1   1.000000  0.313601  0.943468  0.571591  1.000000  0.0
# 2   0.540280  0.661923  0.000000  0.571591  0.722909  0.0
# 3   0.130276  0.539963  0.986993  0.571591  0.722909  0.0
# 4   0.391999  0.943693  0.000965  0.571591  0.000000  0.0
# 5   1.000000  0.647253  0.237290  0.571591  0.722909  0.0
# 6   0.357668  1.000000  0.344781  1.000000  0.000000  0.0
# 7   0.000000  0.941046  0.681259  0.094180  0.000000  1.0
# 8   0.171010  0.539963  0.135951  0.571591  0.722909  0.0
# 9   0.210525  0.948590  0.011415  0.571591  0.000000  0.0
# 10  1.000000  0.539963  0.996589  1.000000  1.000000  1.0
# 11  0.000000  0.941061  0.626248  0.336402  0.000000  1.0
# 12  0.540280  0.312307  0.591253  0.571591  1.000000  0.0
# 13  0.540280  0.992070  0.534602  0.860448  0.000000  0.0
# 14  0.692729  0.539963  1.000000  0.571591  1.000000  1.0
# 15  1.000000  0.539963  0.978873  1.000000  1.000000  0.0
# 16  0.540280  1.000000  0.006098  0.571591  0.000000  0.0
# 17  0.357668  0.673950  0.591253  1.000000  0.722909  1.0
# 18  0.248889  0.986063  0.006098  0.571591  0.000000  1.0
# 19  0.171010  0.064415  0.135951  0.571591  0.722909  0.0
#
#
#
# #### PRINTING X_train ####
# Index(['Age', 'Ticket', 'Fare', 'SibSp', 'Pclass', 'Sex'], dtype='object')
# Age       float64
# Ticket    float64
# Fare      float64
# SibSp     float64
# Pclass    float64
# Sex       float64
# dtype: object
#
#
#          Age    Ticket      Fare     SibSp    Pclass  Sex
# 0   0.461116  0.020766  0.006098  0.571591  0.000000  1.0
# 1   0.000000  0.941046  0.681259  0.094180  0.000000  1.0
# 2   0.130276  0.946524  0.396496  1.000000  0.000000  1.0
# 3   0.338777  0.853730  0.007377  0.571591  0.000000  0.0
# 4   0.000000  0.314378  1.000000  1.000000  1.000000  1.0
# 5   0.323539  0.089147  0.005458  0.571591  0.000000  1.0
# 6   0.489847  0.664792  0.223954  0.571591  0.722909  1.0
# 7   0.286163  0.314364  0.962911  1.000000  1.000000  1.0
# 8   0.226053  0.811864  0.538983  1.000000  0.000000  0.0
# 9   0.580775  0.253368  0.889207  1.000000  1.000000  0.0
# 10  0.171010  0.000000  0.591253  1.000000  0.722909  1.0
# 11  0.210525  0.937706  0.091149  0.571591  0.000000  0.0
# 12  0.580775  0.084355  1.000000  1.000000  1.000000  1.0
# 13  0.913271  0.985217  0.021316  0.571591  0.000000  0.0
# 14  0.357668  1.000000  0.986993  0.860448  0.722909  0.0
# 15  0.000000  0.940975  0.134317  0.571591  0.000000  1.0
# 16  0.551177  0.473494  0.550812  1.000000  0.722909  0.0
# 17  0.000000  0.079430  1.000000  0.571591  1.000000  0.0
# 18  0.322405  1.000000  0.000000  0.571591  0.000000  1.0
# 19  0.551177  0.859122  0.051550  0.571591  0.000000  1.0
#
#
#
# QUICK RESULTS
# 0.6165730337078652
# 0.38342696629213485
# 2
# PRIOR LIST IS [0.61657303 0.38342697]
# XGB val done
# CAT val done
# LGBM val done
# RF val done
# ET val done
# Naive Bayes done
# LR val done
# NN done
# SVC val done
# Shape of ModelDF (9, 14)
# ##Dropping models that behave poorly##
# this is what you are printing [1 2 3 7]
# Accuracy : 84.35754189944134
# MODEL SAVED
#
# Total Model Training Time taken : 13.018762111663818
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       110
#            1       0.80      0.80      0.80        69
#
#     accuracy                           0.84       179
#    macro avg       0.83      0.83      0.83       179
# weighted avg       0.84      0.84      0.84       179
#
# 0 is present in 61% of the Testing Preview
# 1 is present in 39% of the Testing Preview
#
#
# File Saved as preview.csv
#
# Code executed Successfully
#
# ############# END ###########
#      PassengerId  Actual Values  Predicted Values  Class 0 Probabilities  \
# 1            582              1                 1                  0.154
# 2            594              0                 0                  0.605
# 3             49              0                 0                  0.732
# 4            289              1                 0                  0.854
# 5              6              0                 0                  0.771
# ..           ...            ...               ...                    ...
# 96           859              1                 1                  0.354
# 97           269              1                 1                  0.188
# 98           332              0                 0                  0.835
# 99           322              0                 0                  0.841
# 100          272              1                 0                  0.855
#
#      Class 1 Probabilities
# 1                    0.846
# 2                    0.395
# 3                    0.268
# 4                    0.146
# 5                    0.229
# ..                     ...
# 96                   0.646
# 97                   0.812
# 98                   0.165
# 99                   0.159
# 100                  0.145
#
# [100 rows x 5 columns]
# <style  type="text/css" >
#     #T_d9cc1b40_22cb_11eb_b3c3_acde48001122 th {
#           background: rgb(12, 64, 90);
#           background: linear-gradient(0deg, rgba(21, 112, 157) 0%, rgba(12, 64, 90) 120%);
#           padding: 5px;
#           font-family: arial;
#           font-size: 100%;
#           color: white;
#           border: 0.5px;
#           border: solid #0c405a;
#           text-align: center;
#     }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122 td {
#           border: 0.5px;
#           border: solid #0c405a;
#     }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122 caption {
#           text-align: left;
#           font-size: 120%;
#           color: black;
#     }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row0_col0 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row0_col1 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row0_col2 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row0_col3 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row0_col4 {
#             background-color:  #f7f7ba;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row0_col5 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row0_col6 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row0_col7 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row0_col8 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row0_col9 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row0_col10 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row1_col0 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row1_col1 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row1_col2 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row1_col3 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row1_col4 {
#             background-color:  #f7f7ba;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row1_col5 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row1_col6 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row1_col7 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row1_col8 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row1_col9 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row1_col10 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row2_col0 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row2_col1 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row2_col2 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row2_col3 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row2_col4 {
#             background-color:  #f7f7ba;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row2_col5 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row2_col6 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row2_col7 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row2_col8 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row2_col9 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row2_col10 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row3_col0 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row3_col1 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row3_col2 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row3_col3 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row3_col4 {
#             background-color:  #f7f7ba;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row3_col5 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row3_col6 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row3_col7 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row3_col8 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row3_col9 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row3_col10 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row4_col0 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row4_col1 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row4_col2 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row4_col3 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row4_col4 {
#             background-color:  #f7f7ba;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row4_col5 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row4_col6 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row4_col7 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row4_col8 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row4_col9 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row4_col10 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row5_col0 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row5_col1 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row5_col2 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row5_col3 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row5_col4 {
#             background-color:  #f7f7ba;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row5_col5 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row5_col6 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row5_col7 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row5_col8 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row5_col9 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row5_col10 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row6_col0 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row6_col1 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row6_col2 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row6_col3 {
#             background-color:  #e8f7fc;
#         }    #T_d9cc1b40_22cb_11eb_b3c3_acde48001122row6_col4 {
# 	 #### CODE EXECUTED SUCCESSFULLY ####
#
# 	 #### END ####
#
# #### TOTAL TIME TAKEN : 21.26395893096924 ####
# ### SELECTED OPTION EXECUTED SUCCESSFULY ###
# ### QUITTING ###
