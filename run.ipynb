# %% [markdown]
# # Proton Training and Validation Modularized

# %% [markdown]
# ## Dependencies

# %%
# !pip3 install swifter
# !pip3 install xgboost
# !pip3 install tqdm
# !pip3 install category_encoders
# !pip3 install joblib
# !pip3 install scikit-plot
# !pip3 install catboost
# !pip3 install RegscorePy
# !pip3 install -U spacy
# !pip3 install gensim
# !pip3 install xlrd
# !pip3 install lightgbm
# !pip3 install hyperopt
# !pip3 install holidays
# !pip3 install textblob
# !pip3 install pydotplus
# !pip3 install graphviz
# !pip3 install imblearn
# !pip3 install missingpy
# !pip3 install urlextract
# !pip3 install dataframe_image 

# !pip3 install kneed
# !conda install cython
# !conda install numpy scipy
# !conda install scikit-learn
# !pip3 install hdbscan
# !conda install git
# !pip install git+git://github.com/christopherjenness/DBCV.git
# !pip install --upgrade cdbw
# !pip install git+git://github.com/milesgranger/gap_statistic.git
# !pip install git+https://github.com/MaxHalford/Prince
# !python -m spacy download en_core_web_sm

# # Download en_core_web_sm for text analytics

# %%
# WINDOWS R FIX
#set R_HOME dynamically
# import os
# os.environ['R_HOME'] = r'C:\Users\Administrator\anaconda3\envs\proton3\Lib\R' 
# #set R bin
# os.environ['path'] += r';C:\Users\Administrator\anaconda3\envs\proton3\Lib\R\bin;'

# %% [markdown]
# ## Main Function

# %%
import warnings
warnings.filterwarnings('ignore')
from seg_Training import seg_main
def main():
    '''
    PROTON MAIN FUNCTION
    '''
    _ = seg_main()
  
    return 1

if __name__ == '__main__':
    # Main Function call
    ret = main()
# Out:
# Enter the path here : datasets/loandefault.csv
# #### RUNNING WAIT ####
# extension is csv
# We have a csv file
# This file has 41 columns and 30 rows
#
# DataFrame Succesfully imported
#
# Index(['UNIQUEID', 'DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'BRANCH_ID',
#        'SUPPLIER_ID', 'MANUFACTURER_ID', 'CURRENT_PINCODE_ID', 'DATE_OF_BIRTH',
#        'EMPLOYMENT_TYPE', 'DISBURSAL_DATE', 'STATE_ID', 'EMPLOYEE_CODE_ID',
#        'MOBILENO_AVL_FLAG', 'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG',
#        'DRIVING_FLAG', 'PASSPORT_FLAG', 'PERFORM_CNS_SCORE',
#        'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS',
#        'PRI_OVERDUE_ACCTS', 'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT',
#        'PRI_DISBURSED_AMOUNT', 'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS',
#        'SEC_OVERDUE_ACCTS', 'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT',
#        'SEC_DISBURSED_AMOUNT', 'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT',
#        'NEW_ACCTS_IN_LAST_SIX_MONTHS', 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS',
#        'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH', 'NO_OF_INQUIRIES',
#        'LOAN_DEFAULT'],
#       dtype='object')
#
# Enter 'quit' to quit
# Enter the Key/Identification Column :
# Key  Not found in the data
# Preview can't be shown!!
# Is the column 'UNIQUEID' an identification column? If yes, enter y : y
# Identification column UNIQUEID obtained
# Dropping Key from the axis
# Would you like to remove any columns that you dont want to be included in clustering, if so enter the columns in this format separated by commas: col1,col2,col3
# No Columns removed
# Would you like to remove any columns that you dont want to be included in the cluster profiling, if so enter the columns in this format separated by commas: col1,col2,col3
# No Columns removed
# Cluster List ['DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'BRANCH_ID', 'SUPPLIER_ID', 'MANUFACTURER_ID', 'CURRENT_PINCODE_ID', 'DATE_OF_BIRTH', 'EMPLOYMENT_TYPE', 'DISBURSAL_DATE', 'STATE_ID', 'EMPLOYEE_CODE_ID', 'MOBILENO_AVL_FLAG', 'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG', 'DRIVING_FLAG', 'PASSPORT_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS', 'PRI_OVERDUE_ACCTS', 'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT', 'PRI_DISBURSED_AMOUNT', 'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS', 'SEC_OVERDUE_ACCTS', 'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT', 'SEC_DISBURSED_AMOUNT', 'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT', 'NEW_ACCTS_IN_LAST_SIX_MONTHS', 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS', 'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH', 'NO_OF_INQUIRIES', 'LOAN_DEFAULT']
# Profile List ['DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'BRANCH_ID', 'SUPPLIER_ID', 'MANUFACTURER_ID', 'CURRENT_PINCODE_ID', 'DATE_OF_BIRTH', 'EMPLOYMENT_TYPE', 'DISBURSAL_DATE', 'STATE_ID', 'EMPLOYEE_CODE_ID', 'MOBILENO_AVL_FLAG', 'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG', 'DRIVING_FLAG', 'PASSPORT_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS', 'PRI_OVERDUE_ACCTS', 'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT', 'PRI_DISBURSED_AMOUNT', 'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS', 'SEC_OVERDUE_ACCTS', 'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT', 'SEC_DISBURSED_AMOUNT', 'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT', 'NEW_ACCTS_IN_LAST_SIX_MONTHS', 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS', 'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH', 'NO_OF_INQUIRIES', 'LOAN_DEFAULT']
# #### RUNNING WAIT ####
# extension is csv
# We have a csv file
# This file has 41 columns and 233154 rows
#                    Missing in %
# EMPLOYMENT_TYPE            3.29
# UNIQUEID                   0.00
# STATE_ID                   0.00
# PASSPORT_FLAG              0.00
# DRIVING_FLAG               0.00
# VOTERID_FLAG               0.00
# PAN_FLAG                   0.00
# AADHAR_FLAG                0.00
# MOBILENO_AVL_FLAG          0.00
# EMPLOYEE_CODE_ID           0.00
#
#  ### Entering Numeric Engineering of Target###
#
# 		 stripping spaces, symbols, and lower casing all entries
# done ...
# 		 Replacing empty and invalid strings
# done ...
# 		 Replacing commas if present in Currencies
# done ...
# 		 Finding Numeric Columns
# done ...
# 		   DISBURSED_AMOUNT is of type int64
# 		   ASSET_COST is of type int64
# 		   LTV is of type float64
# 		   BRANCH_ID is of type int64
# 		   SUPPLIER_ID is of type int64
# 		   MANUFACTURER_ID is of type int64
# 		   CURRENT_PINCODE_ID is of type int64
# 		   DATE_OF_BIRTH is of type object
# 		   EMPLOYMENT_TYPE is of type object
# 		   DISBURSAL_DATE is of type object
# 		   STATE_ID is of type int64
# 		   EMPLOYEE_CODE_ID is of type int64
# 		   MOBILENO_AVL_FLAG is of type int64
# 		   AADHAR_FLAG is of type int64
# 		   PAN_FLAG is of type int64
# 		   VOTERID_FLAG is of type int64
# 		   DRIVING_FLAG is of type int64
# 		   PASSPORT_FLAG is of type int64
# 		   PERFORM_CNS_SCORE is of type int64
# 		   PERFORM_CNS_SCORE_DESCRIPTION is of type object
# 		   PRI_NO_OF_ACCTS is of type int64
# 		   PRI_ACTIVE_ACCTS is of type int64
# 		   PRI_OVERDUE_ACCTS is of type int64
# 		   PRI_CURRENT_BALANCE is of type int64
# 		   PRI_SANCTIONED_AMOUNT is of type int64
# 		   PRI_DISBURSED_AMOUNT is of type int64
# 		   SEC_NO_OF_ACCTS is of type int64
# 		   SEC_ACTIVE_ACCTS is of type int64
# 		   SEC_OVERDUE_ACCTS is of type int64
# 		   SEC_CURRENT_BALANCE is of type int64
# 		   SEC_SANCTIONED_AMOUNT is of type int64
# 		   SEC_DISBURSED_AMOUNT is of type int64
# 		   PRIMARY_INSTAL_AMT is of type int64
# 		   SEC_INSTAL_AMT is of type int64
# 		   NEW_ACCTS_IN_LAST_SIX_MONTHS is of type int64
# 		   DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS is of type int64
# 		   AVERAGE_ACCT_AGE is of type object
# 		   CREDIT_HISTORY_LENGTH is of type object
# 		   NO_OF_INQUIRIES is of type int64
# 		   LOAN_DEFAULT is of type int64
# Numeric Engineering time taken: 3.124863862991333
#
#
# Init columns are as follows Index(['UNIQUEID', 'DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'BRANCH_ID',
#        'SUPPLIER_ID', 'MANUFACTURER_ID', 'CURRENT_PINCODE_ID', 'DATE_OF_BIRTH',
#        'EMPLOYMENT_TYPE', 'DISBURSAL_DATE', 'STATE_ID', 'EMPLOYEE_CODE_ID',
#        'MOBILENO_AVL_FLAG', 'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG',
#        'DRIVING_FLAG', 'PASSPORT_FLAG', 'PERFORM_CNS_SCORE',
#        'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS',
#        'PRI_OVERDUE_ACCTS', 'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT',
#        'PRI_DISBURSED_AMOUNT', 'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS',
#        'SEC_OVERDUE_ACCTS', 'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT',
#        'SEC_DISBURSED_AMOUNT', 'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT',
#        'NEW_ACCTS_IN_LAST_SIX_MONTHS', 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS',
#        'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH', 'NO_OF_INQUIRIES',
#        'LOAN_DEFAULT'],
#       dtype='object')
#    DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  SUPPLIER_ID  \
# 0             50578       58400  89.55         67        22807
# 1             47145       65550  73.23         67        22807
# 2             53278       61360  89.63         67        22807
# 3             57513       66113  88.48         67        22807
# 4             52378       60300  88.39         67        22807
# 5             54513       61900  89.66         67        22807
# 6             46349       61500  76.42         67        22807
# 7             43894       61900  71.89         67        22807
# 8             53713       61973  89.56         67        22807
# 9             52603       61300  86.95         67        22807
#
#    MANUFACTURER_ID  CURRENT_PINCODE_ID DATE_OF_BIRTH EMPLOYMENT_TYPE  \
# 0               45                1441    01-01-1984        Salaried
# 1               45                1502    31-07-1985   Self employed
# 2               45                1497    24-08-1985   Self employed
# 3               45                1501    30-12-1993   Self employed
# 4               45                1495    09-12-1977   Self employed
# 5               45                1501    08-09-1990   Self employed
# 6               45                1502    01-06-1988        Salaried
# 7               45                1501    04-10-1989        Salaried
# 8               45                1497    15-11-1991   Self employed
# 9               45                1492    01-06-1968        Salaried
#
#   DISBURSAL_DATE  ...  SEC_SANCTIONED_AMOUNT  SEC_DISBURSED_AMOUNT  \
# 0     03-08-2018  ...                      0                     0
# 1     26-09-2018  ...                      0                     0
# 2     01-08-2018  ...                      0                     0
# 3     26-10-2018  ...                      0                     0
# 4     26-09-2018  ...                      0                     0
# 5     19-09-2018  ...                      0                     0
# 6     23-09-2018  ...                      0                     0
# 7     16-09-2018  ...                      0                     0
# 8     05-09-2018  ...                      0                     0
# 9     16-09-2018  ...                      0                     0
#
#    PRIMARY_INSTAL_AMT  SEC_INSTAL_AMT  NEW_ACCTS_IN_LAST_SIX_MONTHS  \
# 0                   0               0                             0
# 1                1991               0                             0
# 2                   0               0                             0
# 3                  31               0                             0
# 4                   0               0                             0
# 5                1347               0                             0
# 6                   0               0                             0
# 7                   0               0                             0
# 8                   0               0                             0
# 9                2608               0                             0
#
#    DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS  AVERAGE_ACCT_AGE  \
# 0                                    0         0yrs 0mon
# 1                                    1        1yrs 11mon
# 2                                    0         0yrs 0mon
# 3                                    0         0yrs 8mon
# 4                                    0         0yrs 0mon
# 5                                    0         1yrs 9mon
# 6                                    0         0yrs 0mon
# 7                                    0         0yrs 2mon
# 8                                    0         4yrs 8mon
# 9                                    0         1yrs 7mon
#
#    CREDIT_HISTORY_LENGTH  NO_OF_INQUIRIES LOAN_DEFAULT
# 0              0yrs 0mon                0            0
# 1             1yrs 11mon                0            1
# 2              0yrs 0mon                0            0
# 3              1yrs 3mon                1            1
# 4              0yrs 0mon                1            1
# 5              2yrs 0mon                0            0
# 6              0yrs 0mon                0            0
# 7              0yrs 2mon                0            0
# 8              4yrs 8mon                1            0
# 9              1yrs 7mon                0            0
#
# [10 rows x 40 columns]
#
# Removing Rows and Columns with more than 50% missing
# Columns are getting dropped first then rows
# The columns getting dropped are []
# Shape of the dataframe: (233154, 40)
# After removal of highly missing rows and columns
#                    Missing in %
# EMPLOYMENT_TYPE            3.29
# LOAN_DEFAULT               0.00
# STATE_ID                   0.00
# PASSPORT_FLAG              0.00
# DRIVING_FLAG               0.00
# VOTERID_FLAG               0.00
# PAN_FLAG                   0.00
# AADHAR_FLAG                0.00
# MOBILENO_AVL_FLAG          0.00
# EMPLOYEE_CODE_ID           0.00
# Shape of X is (233154, 40)
#
# #### LAT-LONG ENGINEERING RUNNING WAIT ####
# returnFloat
# The columns that could be Lat/Long are as follows ['LTV']
# confirmLatLong
# lat columns are []
# long columns are []
# lat-long columns are []
# No Latitude or Longitude Columns found
#
# #### DATE ENGINEERING RUNNING WAIT ####
# Date Columns found are ['DATE_OF_BIRTH', 'DISBURSAL_DATE']
# Respective columns will undergo date engineering and will be imputed in the function itself
#
# #### DATE ENGINEERING RUNNING WAIT ####
#
# 	 Entering Date Engineering
#
# Printing Missing % of date columns
#                 Missing in %
# DISBURSAL_DATE           0.0
# DATE_OF_BIRTH            0.0
# Dropping Columns with missing greater than 35% of total number of entries
#
# 	 #### RUNNING WAIT ####
#
# Visualizing Coloumns Generated
#  {'DATE_OF_BIRTH': ['DATE_OF_BIRTH_month', 'DATE_OF_BIRTH_year', 'DATE_OF_BIRTH-today', 'DATE_OF_BIRTH_nearestHoliday'], 'DISBURSAL_DATE': ['DISBURSAL_DATE_month', 'DISBURSAL_DATE_year', 'DISBURSAL_DATE-today', 'DISBURSAL_DATE_nearestHoliday']}
#
# The Following columns were generated to get days between dates of two seperate date columns
#  ['DATE_OF_BIRTH-DISBURSAL_DATE']
#
# Date Engineering Time Taken : 26.962831020355225
#
# 	 #### DONE ####
# (233154, 9)
#  #### DONE ####
# No Email columns found
# No URL columns found
#
#  ### Entering Segregation Zone ###
#
#
# #### Entering Segregation ####
#
# There are 33 pure numeric columns
# There are 10 categorical numeric columns
#
# The pure numeric columns are Index(['DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'BRANCH_ID', 'SUPPLIER_ID',
#        'MANUFACTURER_ID', 'CURRENT_PINCODE_ID', 'STATE_ID', 'EMPLOYEE_CODE_ID',
#        'PERFORM_CNS_SCORE', 'PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS',
#        'PRI_OVERDUE_ACCTS', 'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT',
#        'PRI_DISBURSED_AMOUNT', 'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS',
#        'SEC_OVERDUE_ACCTS', 'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT',
#        'SEC_DISBURSED_AMOUNT', 'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT',
#        'NEW_ACCTS_IN_LAST_SIX_MONTHS', 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS',
#        'NO_OF_INQUIRIES', 'DATE_OF_BIRTH_month', 'DATE_OF_BIRTH_year',
#        'DATE_OF_BIRTH-today', 'DISBURSAL_DATE_month', 'DISBURSAL_DATE-today',
#        'DATE_OF_BIRTH-DISBURSAL_DATE'],
#       dtype='object')
# The categorical numeric columns are Index(['DATE_OF_BIRTH_Holiday', 'PASSPORT_FLAG', 'PAN_FLAG',
#        'MOBILENO_AVL_FLAG', 'DISBURSAL_DATE_Holiday', 'LOAN_DEFAULT',
#        'AADHAR_FLAG', 'DISBURSAL_DATE_year', 'DRIVING_FLAG', 'VOTERID_FLAG'],
#       dtype='object')
#
# We found 4 obj type columns!
# Printing Cardinality info of All Object Type Columns!
#
# AVERAGE_ACCT_AGE                 192
# CREDIT_HISTORY_LENGTH            294
# PERFORM_CNS_SCORE_DESCRIPTION     20
# EMPLOYMENT_TYPE                    3
# dtype: int64
#
#
# AVERAGE_ACCT_AGE has top 5 levels that contribute to more than 10% of data!
# AVERAGE_ACCT_AGE has 192 levels before grouping
# Attempting grouping of minor levels of AVERAGE_ACCT_AGE as the column has more than 60 levels
# AVERAGE_ACCT_AGE contains 163 categories that is/are less than 0.5 percent
# AVERAGE_ACCT_AGE has 30 levels after grouping
#
# CREDIT_HISTORY_LENGTH has top 5 levels that contribute to more than 10% of data!
# CREDIT_HISTORY_LENGTH has 294 levels before grouping
# Attempting grouping of minor levels of CREDIT_HISTORY_LENGTH as the column has more than 60 levels
# CREDIT_HISTORY_LENGTH contains 255 categories that is/are less than 0.5 percent
# CREDIT_HISTORY_LENGTH has 40 levels after grouping
#
# PERFORM_CNS_SCORE_DESCRIPTION has top 5 levels that contribute to more than 10% of data!
# PERFORM_CNS_SCORE_DESCRIPTION has 20 levels before grouping
# PERFORM_CNS_SCORE_DESCRIPTION is a discrete column!
#
# EMPLOYMENT_TYPE has top 5 levels that contribute to more than 10% of data!
# EMPLOYMENT_TYPE has 3 levels before grouping
# EMPLOYMENT_TYPE is a discrete column!
#
#
# We found 0 unique columns!
#
#
# The unique columns are []
#
# We now have 4 obj type discrete columns!
#
# Printing Cardinality info of obj Discrete Columns!
#
# AVERAGE_ACCT_AGE                 30
# CREDIT_HISTORY_LENGTH            40
# PERFORM_CNS_SCORE_DESCRIPTION    20
# EMPLOYMENT_TYPE                   3
# dtype: int64
# ########################################
# Mean Imputation will be done
#
# Printing Cardinality info of all Discrete Columns! That is categorical numerical + obj type discrete!
#
# DATE_OF_BIRTH_Holiday             2
# PASSPORT_FLAG                     2
# PAN_FLAG                          2
# MOBILENO_AVL_FLAG                 1
# DISBURSAL_DATE_Holiday            2
# LOAN_DEFAULT                      2
# AADHAR_FLAG                       2
# DISBURSAL_DATE_year               1
# DRIVING_FLAG                      2
# VOTERID_FLAG                      2
# AVERAGE_ACCT_AGE                 30
# CREDIT_HISTORY_LENGTH            40
# PERFORM_CNS_SCORE_DESCRIPTION    20
# EMPLOYMENT_TYPE                   3
# dtype: int64
#
# Segregation time taken : 2.342512845993042
# Segregation Done!
#
#  ### TEXT ENGINEERING RUNNING  ###
#
# (150, 0)
# Time taken to tokenize the DataFrame 0.6413090229034424
# Columns that are going to be removed are  []
# Time taken for completion of excess column removal: 0.0002512931823730469
# No Remarks or Comments Found
# Extracting Review Columns time 0.6535701751708984
# No review/comment columns found
# total text analytics time taken = 0.6546761989593506
# Text Engineering Result Empty DataFrame
# Columns: []
# Index: []
#
# #### OUTLIER WINSORIZING ####
#  #### DONE ####
# The shape before Pearson's (233154, 33)
#
#  #### PEARSON CORRELATION ####
# List of columns and how many columns they are corelated to {'PRI_NO_OF_ACCTS': 1, 'PRI_CURRENT_BALANCE': 2, 'PRI_SANCTIONED_AMOUNT': 1, 'DATE_OF_BIRTH_year': 2, 'DATE_OF_BIRTH-today': 1, 'DISBURSAL_DATE_month': 1}
# Dropping DATE_OF_BIRTH_year due to high correlation
# Dropping PRI_CURRENT_BALANCE due to high correlation
# Dropping PRI_SANCTIONED_AMOUNT due to high correlation
# Dropping PRI_NO_OF_ACCTS due to high correlation
# The shape after Pearson's (233154, 29)
#  #### DONE ####
# num_df - (233154, 29)
# disc_df - (233154, 14)
# DATE_DF - (233154, 9)
# TEXT_DF - (0, 0)
# LAT_LONG_DF - (0, 0)
# EMAIL_DF - (0, 0)
# URL_DF -  (0, 0)
# Dropping columns that only contain one value
# Dropping SEC_NO_OF_ACCTS...
# Dropping SEC_ACTIVE_ACCTS...
# Dropping SEC_OVERDUE_ACCTS...
# Dropping SEC_CURRENT_BALANCE...
# Dropping SEC_SANCTIONED_AMOUNT...
# Dropping SEC_DISBURSED_AMOUNT...
# Dropping SEC_INSTAL_AMT...
# Dropping DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS...
# Dropping MOBILENO_AVL_FLAG...
# Dropping DISBURSAL_DATE_year...
#
# Encoding categorical variables
#
#  #### LABEL ENCODING ####
# (233154, 33)
# DISBURSED_AMOUNT                   int64
# ASSET_COST                         int64
# LTV                              float64
# BRANCH_ID                          int64
# SUPPLIER_ID                        int64
# MANUFACTURER_ID                    int64
# CURRENT_PINCODE_ID                 int64
# STATE_ID                           int64
# EMPLOYEE_CODE_ID                   int64
# PERFORM_CNS_SCORE                  int64
# PRI_ACTIVE_ACCTS                   int64
# PRI_OVERDUE_ACCTS                  int64
# PRI_DISBURSED_AMOUNT             float64
# PRIMARY_INSTAL_AMT                 int64
# NEW_ACCTS_IN_LAST_SIX_MONTHS       int64
# NO_OF_INQUIRIES                    int64
# DATE_OF_BIRTH_month                int64
# DATE_OF_BIRTH-today                int64
# DISBURSAL_DATE_month               int64
# DISBURSAL_DATE-today               int64
# DATE_OF_BIRTH-DISBURSAL_DATE       int64
# DATE_OF_BIRTH_Holiday              int64
# PASSPORT_FLAG                      int64
# PAN_FLAG                           int64
# DISBURSAL_DATE_Holiday             int64
# LOAN_DEFAULT                       int64
# AADHAR_FLAG                        int64
# DRIVING_FLAG                       int64
# VOTERID_FLAG                       int64
# AVERAGE_ACCT_AGE                   int64
# CREDIT_HISTORY_LENGTH              int64
# PERFORM_CNS_SCORE_DESCRIPTION      int64
# EMPLOYMENT_TYPE                    int64
# dtype: object
# Target Encoding Time taken : 0.2796671390533447
#
#  #### NORMALIZATION ####
#  #### DONE ####
# (233154, 33)
#
#  #### POWER TRANSFORMATIONS ####
#  #### DONE ####
# (233154, 33)
# The columns that are going into the dimensionality reduction are as follows Index(['DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'BRANCH_ID', 'SUPPLIER_ID',
#        'MANUFACTURER_ID', 'CURRENT_PINCODE_ID', 'STATE_ID', 'EMPLOYEE_CODE_ID',
#        'PERFORM_CNS_SCORE', 'PRI_ACTIVE_ACCTS', 'PRI_OVERDUE_ACCTS',
#        'PRI_DISBURSED_AMOUNT', 'PRIMARY_INSTAL_AMT',
#        'NEW_ACCTS_IN_LAST_SIX_MONTHS', 'NO_OF_INQUIRIES',
#        'DATE_OF_BIRTH_month', 'DATE_OF_BIRTH-today', 'DISBURSAL_DATE_month',
#        'DISBURSAL_DATE-today', 'DATE_OF_BIRTH-DISBURSAL_DATE',
#        'DATE_OF_BIRTH_Holiday', 'PASSPORT_FLAG', 'PAN_FLAG',
#        'DISBURSAL_DATE_Holiday', 'LOAN_DEFAULT', 'AADHAR_FLAG', 'DRIVING_FLAG',
#        'VOTERID_FLAG', 'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH',
#        'PERFORM_CNS_SCORE_DESCRIPTION', 'EMPLOYMENT_TYPE'],
#       dtype='object')
# Calculating number of components....
# <class 'list'>
# <class 'list'>
# The variance captured by each component is
#  [22.344081855962003, 7.355970655442705, 6.706270779431837, 6.080982747941886, 5.4266507108158955, 5.0156257900467764, 4.378143020143253, 4.042059223060243, 3.937687132039073, 3.6650764559402216, 3.0921110453389056, 2.9193441590208193, 2.5898158967274325, 2.5701529008633424, 2.4966797871568738, 2.402740229421927, 2.265699747506277, 2.1639137608579726, 1.9124793332691612, 1.6889429693326758, 1.5518333739630854, 1.45729580924984, 1.1694327781598655, 0.9626546933490165, 0.7570027956328117, 0.32734803605170215, 0.2472941336293372, 0.15832294920821718, 0.12637643661251322, 0.07036403579566641, 0.067934886384877, 0.04472820638127116, 0.004983665262544734]
# ----------------------------------------
# The cumulative variance we capture as we travel through each components are
#  [22.344081855962003, 29.700052511404706, 36.406323290836546, 42.487306038778435, 47.913956749594334, 52.92958253964111, 57.307725559784366, 61.34978478284461, 65.28747191488368, 68.9525483708239, 72.04465941616282, 74.96400357518364, 77.55381947191107, 80.12397237277442, 82.6206521599313, 85.02339238935322, 87.2890921368595, 89.45300589771746, 91.36548523098662, 93.0544282003193, 94.60626157428239, 96.06355738353223, 97.23299016169209, 98.19564485504111, 98.95264765067392, 99.27999568672563, 99.52728982035497, 99.68561276956318, 99.8119892061757, 99.88235324197136, 99.95028812835623, 99.9950163347375, 100.00000000000004]
# Try block Triggered
# Initial PCs could not explain a lot of variance so PCs that account for at least 60% of the cumulative variance is taken
# 8 Principal Components will be generated in dimensionality reduction
# disc_df columns Index(['DATE_OF_BIRTH_Holiday', 'PASSPORT_FLAG', 'PAN_FLAG',
#        'DISBURSAL_DATE_Holiday', 'LOAN_DEFAULT', 'AADHAR_FLAG', 'DRIVING_FLAG',
#        'VOTERID_FLAG', 'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH',
#        'PERFORM_CNS_SCORE_DESCRIPTION', 'EMPLOYMENT_TYPE'],
#       dtype='object')
# Mixed Variables of Numeric and Categorical found, applying FAMD Dimensionality Reduction Technique
# Inside FAMD
#                0         1         2         3         4         5         6  \
# 0      -0.977229 -0.416520 -1.498219  0.228125  0.190328 -0.008645  0.516892
# 1       1.220739 -0.495045  0.098370  0.000776 -0.320595  0.460486 -0.609533
# 2      -0.961502 -0.119623 -1.325997  0.332116 -0.051272  0.433629  0.313895
# 3       0.161638  0.856805  0.202993 -0.678466 -0.160747 -0.031711  0.006339
# 4      -0.695184 -0.136854 -0.787400 -0.566186  0.522111  0.040535  0.453962
# ...          ...       ...       ...       ...       ...       ...       ...
# 233149  1.260822 -0.220367  1.789572  0.325511 -0.264305 -0.267613 -0.196032
# 233150  0.100516  0.589485  1.438716  0.128142 -0.808841 -1.421396  0.523966
# 233151 -1.003750 -0.669635 -0.207629 -0.902756  0.386788 -0.737974 -0.669670
# 233152 -1.250909  0.419104 -0.352001  0.021085 -0.264070  0.130530 -0.906373
# 233153 -1.113328  0.055759  0.723726 -1.113070  0.031797 -0.015017  0.298763
#
#                7
# 0       0.000957
# 1      -0.214999
# 2       0.075408
# 3      -0.440848
# 4      -0.121354
# ...          ...
# 233149  0.045322
# 233150 -0.710619
# 233151  0.004840
# 233152 -0.087952
# 233153  0.111159
#
# [233154 rows x 8 columns]
#
# Performing KMeans...
#   Time taken to run kmeans inside silplots:  00:00:00
