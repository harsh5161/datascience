# %% [markdown]
# # Proton Training and Validation Modularized

# %% [markdown]
# ## Dependencies

# %%
# !pip3 install swifter
# !pip3 install xgboost
# !pip3 install tqdm
# !pip3 install category_encoders
# !pip3 install joblib
# !pip3 install scikit-plot
# !pip3 install catboost
# !pip3 install RegscorePy
# !pip3 install -U spacy
# !pip3 install gensim
# !pip3 install xlrd
# !pip3 install lightgbm
# !pip3 install hyperopt
# !pip3 install holidays
# !pip3 install textblob
# !pip3 install pydotplus
# !pip3 install graphviz
# !pip3 install imblearn
# !pip3 install missingpy
# !pip3 install urlextract
# Download en_core_web_sm for text analytics

# %%
from distributed.versions import get_versions
get_versions()
# Out:
# {'host': {'python': '3.7.7.final.0',
#   'python-bits': 64,
#   'OS': 'Linux',
#   'OS-release': '5.4.0-52-generic',
#   'machine': 'x86_64',
#   'processor': 'x86_64',
#   'byteorder': 'little',
#   'LC_ALL': 'None',
#   'LANG': 'en_IN'},
#  'packages': {'python': '3.7.7.final.0',
#   'dask': '2021.05.0',
#   'distributed': '2021.05.0',
#   'msgpack': '1.0.2',
#   'cloudpickle': '1.5.0',
#   'tornado': '6.1',
#   'toolz': '0.11.1',
#   'numpy': '1.18.1',
#   'lz4': '3.1.1',
#   'blosc': '1.9.2'}}

# %%
from dask.distributed import LocalCluster, Client
client = Client('tcp://a3d95fd82f5524e9094fc0bbb0631bb9-1950175212.us-east-2.elb.amazonaws.com:8786')
client
from distributed.versions import get_versions
get_versions()
# Out:
# ---------------------------------------------------------------------------
# StreamClosedError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/distributed/comm/tcp.py in read(self, deserializers)
#     195         try:
# --> 196             frames_nbytes = await stream.read_bytes(fmt_size)
#     197             (frames_nbytes,) = struct.unpack(fmt, frames_nbytes)
#
# StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# CommClosedError                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/distributed/comm/core.py in connect(addr, timeout, deserialize, handshake_overrides, **connection_args)
#     319         # write, handshake = await asyncio.gather(comm.write(local_info), comm.read())
# --> 320         handshake = await asyncio.wait_for(comm.read(), time_left())
#     321         await asyncio.wait_for(comm.write(local_info), time_left())
#
# ~/anaconda3/lib/python3.7/asyncio/tasks.py in wait_for(fut, timeout, loop)
#     441         if fut.done():
# --> 442             return fut.result()
#     443         else:
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/comm/tcp.py in read(self, deserializers)
#     205             if not sys.is_finalizing():
# --> 206                 convert_stream_closed_error(self, e)
#     207         except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/comm/tcp.py in convert_stream_closed_error(obj, exc)
#     127     else:
# --> 128         raise CommClosedError("in %s: %s" % (obj, exc)) from exc
#     129
#
# CommClosedError: in <closed TCP>: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-ca31aa591f39> in <module>
#       1 from dask.distributed import LocalCluster, Client
# ----> 2 client = Client('tcp://a3d95fd82f5524e9094fc0bbb0631bb9-1950175212.us-east-2.elb.amazonaws.com:8786')
#       3 client
#       4 from distributed.versions import get_versions
#       5 get_versions()
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/client.py in __init__(self, address, loop, timeout, set_as_default, scheduler_file, security, asynchronous, name, heartbeat_interval, serializers, deserializers, extensions, direct_to_workers, connection_limit, **kwargs)
#     750             ext(self)
#     751
# --> 752         self.start(timeout=timeout)
#     753         Client._instances.add(self)
#     754
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/client.py in start(self, **kwargs)
#     966             self._started = asyncio.ensure_future(self._start(**kwargs))
#     967         else:
# --> 968             sync(self.loop, self._start, **kwargs)
#     969
#     970     def __await__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     352     if error[0]:
#     353         typ, exc, tb = error[0]
# --> 354         raise exc.with_traceback(tb)
#     355     else:
#     356         return result[0]
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/utils.py in f()
#     335             if callback_timeout is not None:
#     336                 future = asyncio.wait_for(future, callback_timeout)
# --> 337             result[0] = yield future
#     338         except Exception as exc:
#     339             error[0] = sys.exc_info()
#
# ~/anaconda3/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     760
#     761                     try:
# --> 762                         value = future.result()
#     763                     except Exception:
#     764                         exc_info = sys.exc_info()
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/client.py in _start(self, timeout, **kwargs)
#    1056
#    1057         try:
# -> 1058             await self._ensure_connected(timeout=timeout)
#    1059         except (OSError, ImportError):
#    1060             await self._close()
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/client.py in _ensure_connected(self, timeout)
#    1114         try:
#    1115             comm = await connect(
# -> 1116                 self.scheduler.address, timeout=timeout, **self.connection_args
#    1117             )
#    1118             comm.name = "Client->Scheduler"
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/comm/core.py in connect(addr, timeout, deserialize, handshake_overrides, **connection_args)
#     325         raise IOError(
#     326             f"Timed out during handshake while connecting to {addr} after {timeout} s"
# --> 327         ) from exc
#     328
#     329     comm.remote_info = handshake
#
# OSError: Timed out during handshake while connecting to tcp://a3d95fd82f5524e9094fc0bbb0631bb9-1950175212.us-east-2.elb.amazonaws.com:8786 after 10 s

# %% [markdown]
# ## Main Function

# %%
from dask.distributed import LocalCluster, Client
client = Client('tcp://a3d95fd82f5524e9094fc0bbb0631bb9-1950175212.us-east-2.elb.amazonaws.com:8786')
client
import sys
sys.setrecursionlimit(150000)
from userInputs import *
from INIT import *
from score import *
from all_other_functions import targetAnalysis
import time
import pandas as pd
import numpy as np
import swifter
import joblib
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import re
from sklearn.model_selection import train_test_split
from engineerings import numeric_engineering
def main():
    '''
    PROTON MAIN FUNCTION
    '''
    spinnerBool = False
    path = input('Enter the path here : ')
    error = False
    if path:
        print("Attempting to import 100 rows of the dataset")
        try:
            df,csvPath = importFile(path,nrows=100)
        except ValueError:
            error_text = "Insufficient Data Error, Please collect more information"
        df = df.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
        df = duplicateHandler(df)
        df,update = dataHandler(df) # If first few rows contains unnecessary info
        df = duplicateHandler(df)
        info = getUserInput(df)
        if not info:
            error = True
    else:
        df = None
        print('\nInitial Import Failed, Quitting Process\n')
        info = None
        error = True

    te = time.time()
    try:
        if info:
            spinnerBool = True
            ################## TRAINING INIT ##################
            if csvPath:
                path = 'SheetSheetSheet.csv'
            df,_ = importFile(path,nrows=None)
            df = df.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
            df = duplicateHandler(df)
            df,update = dataHandler(df) # If first few rows contains unnecessary info
            df = duplicateHandler(df)
            if update is True: #If columns are removed in dataHandler() 
                cols = df.columns.to_list()
                cols.remove(info['target'])
                info['cols'] = cols
            tts = time.time()
            if isinstance(df,pd.DataFrame):
                target = info['target']
                print("###Performing Initial Numeric Engineering for Capping Purposes###")
#                 print("Initial columns",df.columns.to_list())
                dfsamp = df.sample(n=1000,random_state=1) if len(df)>1000 else df.copy()
                dfsamp = numeric_engineering(dfsamp)
                dfsamp = dfsamp.dropna(axis=0,subset=[target])
                print("###Estimating the type of target for Capping Purposes###")
                class_or_Reg = targetAnalysis(dfsamp[target])                    
                if class_or_Reg == 'Classification':
                    if len(df) >1000000:
                        df_train, _ = train_test_split(df, train_size=1000000,random_state=1, stratify=df[target])
                        print("Dataset size has been capped to 1 million rows for better performance")
                        print("Length of the dataset is now",len(df_train))
                        init_info,validation = INIT(df_train,info)
                    else:
                        print("Dataset has not been capped")
                        print("Length of the dataset is same as original",len(df))
                        init_info,validation = INIT(df,info)
                elif class_or_Reg == 'Regression':
                    dfr = df.sample(n=1000000, random_state=1) if len(df)>1000000 else df.copy()
                    print("Dataset size has been capped to 1 million rows for better performance")
                    print("Length of the dataset is now",len(dfr))
                    init_info,validation = INIT(dfr,info)
                elif class_or_Reg is None:
                    init_info,validation = None,None
            else:
                init_info,validation = None,None
            tte = time.time()
            print('\n TOTAL TRAINING DATA CLEANING AND PLOTS : {}'.format(tte-tts))
            ################## TRAINING INIT ##################

            if isinstance(validation,pd.DataFrame):
                ################## VALIDATION AND PREDICTION ##################
                score(validation,init_info,validation=True)
                ################## VALIDATION AND PREDICTION ##################
                print('\n\t #### CODE EXECUTED SUCCESSFULLY ####')
                print('\n\t #### END ####')
            else:
                print('\n\t #### CODE DID NOT RUN COMPLETELY ####')
            spinnerBool = False
    except KeyboardInterrupt:
        print('QUITTING!')
        client.close()
        return None
#     except Exception as e:
#         print('Code did not run completely')
#         print('Code ran into an error')
#         print('The error message received is')
#         print(e)
#         return None
    ee = time.time()
    print('\n#### TOTAL TIME TAKEN : {} ####'.format(ee-te))
    client.close()
    return 1

if __name__ == '__main__':
    # Main Function call
    ret = main()
# Out:
# Enter the path here : titanic.csv
# Attempting to import 100 rows of the dataset
# #### RUNNING WAIT ####
# extension is csv
# We have a csv file
# This file has 12 columns and 100 rows
#
# DataFrame Succesfully imported
#
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#
# Enter 'quit' to quit
# What would you like to predict? : Age
# Target Spotted!
#
# Enter 'quit' to quit
# Enter the Key/Identification Column :
# Key  Not found in the data
# Preview can't be shown!!
# Is the column 'PassengerId' an identification column? If yes, enter y : y
# Identification column obtained
# Do you think you have Successive Targets based on the current target? If yes, enter the column names below
# in this format separated by commas: col1,col2,col3
#
# No Columns removed
# Would you like to remove any other ID,zip Code,Phone Numbers,UNIQUE lists,
# Or columns that have only one unique entry? If yes, enter the column names below
# in this format separated by commas: col1,col2,col3
#
# No Columns removed
# Do you want quick results or slower results? If quick enter y : q
# HyperOP with MAX EVALS = 15
# Do you want to disable graphs for this output session? If disable press y : y
# Graphs are now turned off for this output session
# #### RUNNING WAIT ####
# extension is csv
# We have a csv file
# This file has 12 columns and 891 rows
# ###Performing Initial Numeric Engineering for Capping Purposes###
# 		 stripping spaces, symbols, and lower casing all entries
# done ...
# 		 Replacing empty and invalid strings
# done ...
# 		 Replacing commas if present in Currencies
# done ...
# 		 Finding Numeric Columns
# done ...
# 		   PassengerId is of type int64
# 		   Survived is of type int64
# 		   Pclass is of type int64
# 		   Name is of type object
# 		   Sex is of type object
# 		   Age is of type float64
# 		   SibSp is of type int64
# 		   Parch is of type int64
# 		   Ticket is of type float64
# 		   Fare is of type float64
# 		   Cabin is of type object
# 		   Embarked is of type object
# Numeric Engineering time taken: 0.08951091766357422
#
#
# ###Estimating the type of target for Capping Purposes###
#
# ### TARGET ANALYSIS ENTERED ###
# Target has 88 unique values
# Printing % occurence of each class in target Column
# 24.00    0.042017
# 22.00    0.037815
# 18.00    0.036415
# 28.00    0.035014
# 19.00    0.035014
#            ...
# 55.50    0.001401
# 74.00    0.001401
# 0.92     0.001401
# 70.50    0.001401
# 12.00    0.001401
# Name: Age, Length: 88, dtype: float64
# Dataset size has been capped to 1 million rows for better performance
# Length of the dataset is now 891
# Length of the dataframe entering INIT is:  891
#           Missing in %
# Cabin            77.10
# Age              19.87
# Embarked          0.22
# Survived          0.00
# Pclass            0.00
# Name              0.00
# Sex               0.00
# SibSp             0.00
# Parch             0.00
# Ticket            0.00
#
#  ### Entering Numeric Engineering of Target###
#
# 		 stripping spaces, symbols, and lower casing all entries
# done ...
# 		 Replacing empty and invalid strings
# done ...
# 		 Replacing commas if present in Currencies
# done ...
# 		 Finding Numeric Columns
# done ...
# 		   Survived is of type int64
# 		   Pclass is of type int64
# 		   Name is of type object
# 		   Sex is of type object
# 		   SibSp is of type int64
# 		   Parch is of type int64
# 		   Ticket is of type float64
# 		   Fare is of type float64
# 		   Cabin is of type object
# 		   Embarked is of type object
# 		   Age is of type float64
# Numeric Engineering time taken: 0.03841662406921387
#
#
# Target Analysis
#
# ### TARGET ANALYSIS ENTERED ###
# Target has 88 unique values
# Printing % occurence of each class in target Column
# 24.00    0.042017
# 22.00    0.037815
# 18.00    0.036415
# 28.00    0.035014
# 19.00    0.035014
#            ...
# 55.50    0.001401
# 74.00    0.001401
# 0.92     0.001401
# 70.50    0.001401
# 12.00    0.001401
# Name: Age, Length: 88, dtype: float64
# Age column needs Regression
#
#  177 rows were removed since target had these missing
# Target Unique values and count
#  24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 55.50     1
# 74.00     1
# 0.92      1
# 70.50     1
# 12.00     1
# Name: Age, Length: 88, dtype: int64
#  Unique values
#  88
#
# Removing Rows and Columns with more than 50% missing
#
# Rows/Columns will get dropped
# Rows are getting dropped first then rows
# The columns getting dropped are ['Cabin']
# Shape of the dataframe: (571, 9)
# Shape of the target column (571,)
# After removal of highly missing rows and columns
#           Missing in %
# Ticket           28.02
# Embarked          0.35
# Survived          0.00
# Pclass            0.00
# Name              0.00
# Sex               0.00
# SibSp             0.00
# Parch             0.00
# Fare              0.00
# Shape of X_train is (571, 9)
# Shape of y_train is (571,)
# Checking if there are labels present in validation that arent present in training
#
# #### LAT-LONG ENGINEERING RUNNING WAIT ####
# returnFloat
# The columns that could be Lat/Long are as follows ['Ticket', 'Fare']
# confirmLatLong
# lat columns are []
# long columns are []
# lat-long columns are []
# No Latitude or Longitude Columns found
#
# #### DATE ENGINEERING RUNNING WAIT ####
# Date Columns found are []
#  #### DONE ####
#
# #### EMAIL ENGINEERING RUNNING WAIT ####
# No Email columns found
#
# #### URL ENGINEERING RUNNING WAIT ####
# No URL columns found
#
#  ### Entering Segregation Zone ###
#
#
# #### Entering Segregation ####
#
# There are 2 pure numeric columns
# There are 4 categorical numeric columns
#
# The pure numeric columns are Index(['Ticket', 'Fare'], dtype='object')
# The categorical numeric columns are Index(['SibSp', 'Parch', 'Survived', 'Pclass'], dtype='object')
#
# We found 3 obj type columns!
# Printing Cardinality info of All Object Type Columns!
#
# Name        571
# Embarked      4
# Sex           2
# dtype: int64
#
#
# Name has top 5 levels that contribute to less than 10% of data!
# Name is unique
#
# Embarked has top 5 levels that contribute to more than 10% of data!
# Embarked has 4 levels before grouping
# Embarked is a discrete column!
#
# Sex has top 5 levels that contribute to more than 10% of data!
# Sex has 2 levels before grouping
# Sex is a discrete column!
#
#
# We found 1 unique columns!
#
#
# The unique columns are ['Name']
#
# We now have 2 obj type discrete columns!
#
# Printing Cardinality info of obj Discrete Columns!
#
# Embarked    4
# Sex         2
# dtype: int64
# ############################
# MissForest Imputation can be attempted
#
# ### TARGET ANALYSIS ENTERED ###
# Target has 48 unique values
# Printing % occurence of each class in target Column
# 50.0    0.108581
# 14.0    0.101576
# 24.0    0.043783
# 18.0    0.040280
# 30.0    0.036778
# 22.0    0.035026
# 28.0    0.035026
# 21.0    0.035026
# 36.0    0.031524
# 29.0    0.031524
# 19.0    0.031524
# 25.0    0.029772
# 35.0    0.028021
# 26.0    0.026270
# 16.0    0.026270
# 27.0    0.024518
# 23.0    0.022767
# 20.0    0.022767
# 32.0    0.022767
# 42.0    0.021016
# 34.0    0.021016
# 31.0    0.019264
# 40.0    0.019264
# 39.0    0.017513
# 38.0    0.017513
# 17.0    0.017513
# 45.0    0.014011
# 48.0    0.014011
# 44.0    0.014011
# 33.0    0.014011
# 49.0    0.008757
# 41.0    0.008757
# 37.0    0.008757
# 47.0    0.008757
# 43.0    0.007005
# 46.0    0.005254
# 15.0    0.005254
# 40.5    0.003503
# 32.5    0.003503
# 30.5    0.003503
# 28.5    0.001751
# 23.5    0.001751
# 24.5    0.001751
# 14.5    0.001751
# 45.5    0.001751
# 36.5    0.001751
# 34.5    0.001751
# 20.5    0.001751
# Name: Age, dtype: float64
# MissForest imputation will be done...
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Time taken for the completion of MissForest is : 5.685081958770752
#
# Printing Cardinality info of all Discrete Columns! That is categorical numerical + obj type discrete!
#
# SibSp       6
# Parch       7
# Survived    2
# Pclass      3
# Embarked    4
# Sex         2
# dtype: int64
#
# Segregation time taken : 5.83154559135437
# Segregation Done!
# Useless Columns are ['Name']
# Name count of words is 0 - 0 - 46 - 74 -
# dropping column Name
# (150, 0)
# Time taken to tokenize the DataFrame 0.6220500469207764
# Columns that are going to be removed are  ['Name']
# Time taken for completion of excess column removal: 0.000885009765625
# No Remarks or Comments Found
# Extracting Review Columns time 0.6343700885772705
# No review/comment columns found
# total text analytics time taken = 0.6354422569274902
# Text Engineering Result Empty DataFrame
# Columns: []
# Index: []
#
# #### OUTLIER WINSORIZING ####
#  #### DONE ####
# The shape before Pearson's (571, 2)
#
#  #### PEARSON CORRELATION ####
# List of columns and how many columns they are corelated to {}
# No columns are correlated
# The shape after Pearson's (571, 2)
#  #### DONE ####
# num_df - (571, 2)
# disc_df - (571, 6)
# DATE_DF - (0, 0)
# TEXT_DF - (0, 0)
# LAT_LONG_DF - (0, 0)
# EMAIL_DF - (0, 0)
# URL_DF - (0, 0)
#
#  #### TARGET ENCODING ####
# (571, 8)
# (571,)
# Target Encoding Time taken : 0.143019437789917
#
#  #### FEATURE SELECTION SKIPPED BECAUSE COLUMNS LESS THAN 10 ####
#
#  #### SCALING ####
#  #### SCALING DONE ####
# (571, 8)
# (571,)
#
#  #### POWER TRANSFORMATIONS ####
#  #### POWER TRANSFORMATIONS DONE ####
# (571, 8)
# (571,)
#
#  #### Printing Sample Equation of the DATA ####
# LABEL ENCODED FOR SAMPLE EQUATION
# No module named 'mlxtend'
# SAMPLE EQUATION DID NOT RUN AND HAD ERRORS!!!
#  #### DONE ####
#
# This is final shape of X_train : (571, 8)
# This is final shape of Y_train : (571,)
#
#
#  #### SAVING INIT INFORMATION ####
#  #### DONE ####
#
#  TOTAL TRAINING DATA CLEANING AND PLOTS : 9.133213758468628
#
# 	 #### VALIDATION AND SCORING ZONE ####
# Target Unique values and count
#  14.0    19
# 50.0    12
# 19.0     7
# 33.0     7
# 22.0     7
# 31.0     6
# 25.0     6
# 32.0     5
# 24.0     5
# 28.0     5
# 21.0     4
# 30.0     4
# 45.0     4
# 36.0     4
# 27.0     4
# 39.0     4
# 47.0     4
# 26.0     3
# 17.0     3
# 34.0     3
# 18.0     3
# 40.0     2
# 16.0     2
# 23.0     2
# 20.0     2
# 35.0     2
# 15.0     2
# 29.0     2
# 45.5     1
# 41.0     1
# 49.0     1
# 43.0     1
# 28.5     1
# 37.0     1
# 42.0     1
# 48.0     1
# 44.0     1
# 38.0     1
# Name: Age, dtype: int64
#  Unique values
#  38
# Value of Key from Training is:  PassengerId
# Total no. of null values present in the Key:  0
# NUll values after removal are:  0
# Pandas Apply:   0%|          | 0/2 [00:00<?, ?it/s]
# Shape after Pearsons Correlation (143, 2)
# num_df - (143, 2)
# disc_df - (143, 6)
# DATE_DF - (0, 0)
# TEXT_DF - (0, 0)
# LAT_LONG_DF - (0, 0)
# EMAIL_DF - (0, 0)
# URL_DF - (0, 0)
# Applying Target Encoding...
# Target Encoding completed
# Applying Scaling and Transformations on Validation Set...
# Scaling and Transformation completed
#
# This is final shape of X_test : (143, 8)
#
#  #### PRINTING THE LIST OF COLUMNS AND ITS TYPES THAT ENTER THE MODEL TRAINING ####
# #### PRINTING X_test ####
# Index(['Ticket', 'Fare', 'SibSp', 'Parch', 'Survived', 'Pclass', 'Embarked',
#        'Sex'],
#       dtype='object')
# Ticket      float64
# Fare        float64
# SibSp       float64
# Parch       float64
# Survived    float64
# Pclass      float64
# Embarked    float64
# Sex         float64
# dtype: object
#
#
#       Ticket      Fare     SibSp     Parch  Survived    Pclass  Embarked  Sex
# 0   0.040324  1.000000  0.855175  0.214086       0.0  1.000000  0.545603  0.0
# 1   1.000000  0.621822  0.000000  0.214086       1.0  0.000000  0.000000  1.0
# 2   0.047413  0.565430  0.855175  0.000000       0.0  0.622751  0.545603  0.0
# 3   0.662480  0.637433  1.000000  0.357986       0.0  0.622751  1.000000  0.0
# 4   0.766675  0.014283  0.855175  0.357986       1.0  0.000000  0.545603  1.0
# 5   0.679929  0.219079  0.855175  0.357986       1.0  0.622751  0.545603  1.0
# 6   0.766675  0.247117  0.855175  0.357986       0.0  0.622751  1.000000  0.0
# 7   0.316179  0.575926  0.855175  0.357986       1.0  1.000000  0.545603  1.0
# 8   0.053370  0.219079  0.855175  0.357986       1.0  0.622751  0.545603  1.0
# 9   0.652169  0.219079  0.855175  0.357986       1.0  0.622751  0.545603  1.0
# 10  0.680056  0.565430  0.855175  0.357986       1.0  0.622751  0.545603  1.0
# 11  0.766675  0.073498  0.855175  0.357986       1.0  0.000000  0.545603  1.0
# 12  0.000000  0.000000  0.855175  0.357986       1.0  0.000000  1.000000  1.0
# 13  0.696671  0.219079  0.855175  0.357986       1.0  0.622751  0.545603  1.0
# 14  0.939561  0.080062  0.855175  0.357986       1.0  0.000000  0.545603  1.0
# 15  0.766675  0.316452  1.000000  0.214086       0.0  0.000000  0.545603  1.0
# 16  0.000000  0.269714  1.000000  0.357986       1.0  0.000000  1.000000  1.0
# 17  0.766675  0.000000  0.855175  0.357986       1.0  0.000000  0.545603  1.0
# 18  0.766675  0.008361  0.855175  0.357986       0.0  0.000000  0.545603  1.0
# 19  0.939524  0.057971  0.855175  0.357986       1.0  0.000000  0.545603  1.0
#
#
#
# #### PRINTING X_train ####
# Index(['Ticket', 'Fare', 'SibSp', 'Parch', 'Survived', 'Pclass', 'Embarked',
#        'Sex'],
#       dtype='object')
# Ticket      float64
# Fare        float64
# SibSp       float64
# Parch       float64
# Survived    float64
# Pclass      float64
# Embarked    float64
# Sex         float64
# dtype: object
#
#
#       Ticket      Fare         SibSp     Parch  Survived    Pclass  Embarked  \
# 0   0.000000  0.269714  1.000000e+00  0.357986       0.0  0.000000  0.897151
# 1   1.000000  0.528165  3.023196e-03  0.357986       1.0  0.000000  0.489488
# 2   0.642054  0.565430  8.551748e-01  0.000000       1.0  0.622751  0.489488
# 3   0.948037  0.006971  8.551748e-01  0.357986       1.0  0.000000  0.489488
# 4   1.000000  0.000000  8.551748e-01  0.357986       0.0  0.000000  0.000000
# 5   0.948027  0.006971  8.551748e-01  0.357986       1.0  0.000000  0.489488
# 6   0.942729  0.001199  8.551748e-01  0.357986       1.0  0.000000  0.489488
# 7   0.359828  0.289254  8.551748e-01  0.357986       1.0  0.622751  0.897151
# 8   0.668140  0.565430  8.551748e-01  0.357986       1.0  0.622751  0.489488
# 9   0.948049  0.006971  8.551748e-01  0.357986       1.0  0.000000  0.489488
# 10  0.982694  0.014283  8.551748e-01  0.357986       1.0  0.000000  0.489488
# 11  0.026686  1.000000  1.000000e+00  0.357986       0.0  1.000000  0.489488
# 12  0.086222  0.905445  1.000000e+00  0.357986       0.0  1.000000  0.897151
# 13  0.950119  0.004988  8.551748e-01  0.357986       1.0  0.000000  0.489488
# 14  0.000000  0.000000  8.551748e-01  0.357986       1.0  0.000000  0.897151
# 15  0.000000  0.565430  8.551748e-01  0.357986       1.0  1.000000  0.489488
# 16  1.000000  0.834841  4.369300e-08  0.000000       1.0  0.000000  0.489488
# 17  0.862843  0.042713  8.551748e-01  0.357986       1.0  0.000000  0.489488
# 18  0.740740  0.014283  8.551748e-01  0.357986       1.0  0.000000  0.489488
# 19  0.000000  0.094100  1.000000e+00  0.357986       1.0  0.000000  0.489488
#
#     Sex
# 0   0.0
# 1   1.0
# 2   1.0
# 3   1.0
# 4   0.0
# 5   1.0
# 6   1.0
# 7   1.0
# 8   1.0
# 9   1.0
# 10  1.0
# 11  1.0
# 12  1.0
# 13  1.0
# 14  1.0
# 15  1.0
# 16  1.0
# 17  1.0
# 18  1.0
# 19  0.0
#
#
#
# Modelling...
# The value of Q_S is  False
# HYPER OP
# {'colsample_bytree': 0.9944023958657515, 'eta': 0.06821567990420681, 'eval_metric': 'rmse', 'gamma': 9, 'max_depth': 20, 'min_child_weight': 12, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.8748828323228355}
# XGB Training Done
# {'colsample_bytree': 0.9637937815718349, 'eta': 0.06337772267267751, 'eval_metric': 'rmse', 'gamma': 6, 'max_depth': 20, 'min_child_weight': 10, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.6468044700026173}
# XGB Training Done
# {'colsample_bytree': 0.9922781795244613, 'eta': 0.09010173407700463, 'eval_metric': 'rmse', 'gamma': 0, 'max_depth': 20, 'min_child_weight': 13, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.963457655052001}
# XGB Training Done
# {'colsample_bytree': 0.3484840087837505, 'eta': 0.061389576337345736, 'eval_metric': 'rmse', 'gamma': 1, 'max_depth': 20, 'min_child_weight': 12, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.7786620391654238}
# XGB Training Done
# {'colsample_bytree': 0.5467155365431469, 'eta': 0.03570999432331255, 'eval_metric': 'rmse', 'gamma': 9, 'max_depth': 20, 'min_child_weight': 13, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.8514199777646063}
# XGB Training Done
# {'colsample_bytree': 0.865245715531652, 'eta': 0.08609455804570655, 'eval_metric': 'rmse', 'gamma': 12, 'max_depth': 20, 'min_child_weight': 10, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.6373554825540861}
# XGB Training Done
# {'colsample_bytree': 0.3835720251358117, 'eta': 0.0745149149053474, 'eval_metric': 'rmse', 'gamma': 11, 'max_depth': 20, 'min_child_weight': 10, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.8586593249182232}
# XGB Training Done
# {'colsample_bytree': 0.45191802670137493, 'eta': 0.06012732351505976, 'eval_metric': 'rmse', 'gamma': 3, 'max_depth': 20, 'min_child_weight': 10, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.8924301946032123}
# XGB Training Done
# {'colsample_bytree': 0.23359327086725676, 'eta': 0.01973010605191443, 'eval_metric': 'rmse', 'gamma': 6, 'max_depth': 20, 'min_child_weight': 3, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.8853711024975628}
# XGB Training Done
# {'colsample_bytree': 0.582945077171881, 'eta': 0.07072002951889408, 'eval_metric': 'rmse', 'gamma': 6, 'max_depth': 20, 'min_child_weight': 8, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.9007572847641226}
# XGB Training Done
# {'colsample_bytree': 0.8353137193975211, 'eta': 0.019369431739818845, 'eval_metric': 'rmse', 'gamma': 4, 'max_depth': 20, 'min_child_weight': 15, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.9927177513435379}
# XGB Training Done
# {'colsample_bytree': 0.7639084998709709, 'eta': 0.02937271329503075, 'eval_metric': 'rmse', 'gamma': 4, 'max_depth': 20, 'min_child_weight': 7, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.9888489969428617}
# XGB Training Done
# {'colsample_bytree': 0.5288899191067673, 'eta': 0.0650980901566376, 'eval_metric': 'rmse', 'gamma': 10, 'max_depth': 20, 'min_child_weight': 15, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.7885175297480438}
# XGB Training Done
# {'colsample_bytree': 0.7859581750752207, 'eta': 0.09343059869927132, 'eval_metric': 'rmse', 'gamma': 5, 'max_depth': 20, 'min_child_weight': 11, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.8282066997613131}
# XGB Training Done
# {'colsample_bytree': 0.2155578718841641, 'eta': 0.014103863529278195, 'eval_metric': 'rmse', 'gamma': 11, 'max_depth': 20, 'min_child_weight': 2, 'n_estimators': 100, 'objective': 'reg:squarederror', 'subsample': 0.8230600735247304}
# XGB Training Done
# 100%|██████████| 15/15 [00:37<00:00,  2.51s/trial, best loss: 0.8698745048228396]
# XGB hyperop done
# <class 'list'>
# XGB Validation done
# CAT Validation done
# Moving into HyperOp
# {'boosting_type': 'gbdt', 'learning_rate': 0.0980018828788365, 'max_depth': 16, 'min_child_weight': 13, 'n_estimators': 100, 'num_leaves': 32, 'random_state': 1, 'subsample': 0.8630186906598208}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.08856599594774481, 'max_depth': 16, 'min_child_weight': 7, 'n_estimators': 100, 'num_leaves': 38, 'random_state': 1, 'subsample': 0.9534009594056857}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.07443868008894937, 'max_depth': 16, 'min_child_weight': 3, 'n_estimators': 100, 'num_leaves': 42, 'random_state': 1, 'subsample': 0.8135912972425335}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.029557381423181733, 'max_depth': 16, 'min_child_weight': 6, 'n_estimators': 100, 'num_leaves': 33, 'random_state': 1, 'subsample': 0.8395267140750191}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.08672283491649443, 'max_depth': 16, 'min_child_weight': 10, 'n_estimators': 100, 'num_leaves': 33, 'random_state': 1, 'subsample': 0.924936632360194}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.03730682272637306, 'max_depth': 16, 'min_child_weight': 13, 'n_estimators': 100, 'num_leaves': 37, 'random_state': 1, 'subsample': 0.9441929846202914}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.04131959607935107, 'max_depth': 16, 'min_child_weight': 10, 'n_estimators': 100, 'num_leaves': 39, 'random_state': 1, 'subsample': 0.7090097722811194}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.0329812429439046, 'max_depth': 16, 'min_child_weight': 1, 'n_estimators': 100, 'num_leaves': 34, 'random_state': 1, 'subsample': 0.8496562670158354}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.05550799706158586, 'max_depth': 16, 'min_child_weight': 9, 'n_estimators': 100, 'num_leaves': 38, 'random_state': 1, 'subsample': 0.8990120020609009}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.04188332603405855, 'max_depth': 16, 'min_child_weight': 4, 'n_estimators': 100, 'num_leaves': 30, 'random_state': 1, 'subsample': 0.9774083312542711}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.09816966015906667, 'max_depth': 16, 'min_child_weight': 16, 'n_estimators': 100, 'num_leaves': 40, 'random_state': 1, 'subsample': 0.8236075208982783}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.05553980769394268, 'max_depth': 16, 'min_child_weight': 7, 'n_estimators': 100, 'num_leaves': 39, 'random_state': 1, 'subsample': 0.8111680484048545}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.0523750484536603, 'max_depth': 16, 'min_child_weight': 16, 'n_estimators': 100, 'num_leaves': 36, 'random_state': 1, 'subsample': 0.8736327199275639}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.07521304906190984, 'max_depth': 16, 'min_child_weight': 7, 'n_estimators': 100, 'num_leaves': 40, 'random_state': 1, 'subsample': 0.9536543908586426}
# XGB Training Done
# {'boosting_type': 'gbdt', 'learning_rate': 0.06900220959013238, 'max_depth': 16, 'min_child_weight': 4, 'n_estimators': 100, 'num_leaves': 40, 'random_state': 1, 'subsample': 0.7455836896750647}
# XGB Training Done
# 100%|██████████| 15/15 [00:35<00:00,  2.40s/trial, best loss: 0.9265963562677756]
# HyperOP done for LGBM
# LGBM done
# LGBM val done
# {'bootstrap': False, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 20, 'min_samples_split': 13, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': True, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 15, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': True, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 14, 'min_samples_split': 6, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': True, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': False, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 20, 'min_samples_split': 13, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': False, 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': True, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 17, 'min_samples_split': 11, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': True, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 11, 'min_samples_split': 10, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': True, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': True, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 13, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': False, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 19, 'min_samples_split': 10, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': False, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 17, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': False, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 12, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# {'bootstrap': False, 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 19, 'min_samples_split': 11, 'n_estimators': 100, 'oob_score': False}
# Random Forest Training done
# 100%|██████████| 15/15 [00:13<00:00,  1.14trial/s, best loss: 0.8365817830648463]
# HyperOP done for RF
# RF Hyperop done
# RF done
# RF Validation done
# ETextra_reg_prob1 Validation done
# ridge reg done
# linear reg done
# SVC done
# this is what you are printing [0 1 2 6]
# Accuracy : 31.324765720994417
# Modelling completed
# MODEL SAVED
#
# Total Model Training Time taken : 106.49867177009583
# Distribution of Mean of Actual and Predicted Values by Deciles:
# +----------+--------------------+-----------------------+
# |   Decile |   Actualvalue_mean |   Predictedvalue_mean |
# |----------+--------------------+-----------------------|
# |        1 |              49.79 |                 36.03 |
# |        2 |              44.54 |                 31.42 |
# |        3 |              37.07 |                 31.08 |
# |        4 |              32.79 |                 28.28 |
# |        5 |              30.04 |                 28.77 |
# |        6 |              26.64 |                 28.28 |
# |        7 |              23.5  |                 29.11 |
# |        8 |              20.36 |                 27.38 |
# |        9 |              16.64 |                 27.27 |
# |       10 |              14    |                 20.82 |
# +----------+--------------------+-----------------------+
#
# File Saved as preview.csv
#
# Code executed Successfully
#
# ############# END ###########
#
# 	 #### CODE EXECUTED SUCCESSFULLY ####
#
# 	 #### END ####
#
# #### TOTAL TIME TAKEN : 119.68517661094666 ####

# %%
pre = pd.read_csv('preview.csv')
pre.index = np.arange(1,len(pre)+1)

# Set CSS properties for th elements in dataframe
th_prop = [
    ('padding', '5px'),
    ('font-family', 'arial'),
    ('font-size', '100%'),
    ('color', 'Black'),
    ('border', '0.5px') ,
    ('border', 'solid black'),
    ('text-align', 'center')
  ]

# Set CSS properties for td elements in dataframe
td_prop = [
#     ('background', 'rgb(232, 247, 252)'),
    ('border', '0.5px'),
    ('border','solid black'),
    ('color', 'black'),
    ('font-family', 'arial')
  ]

# Set table styles
styls = [
  dict(selector="th", props=th_prop),
  dict(selector="td", props=td_prop),
  dict(selector="caption", props=[("text-align", "left"),("font-size", "120%"),("color", 'black')])
  ]

# pre.style.set_table_styles(styls).set_caption("Preview of Test Dataset(100 rows) with Predictions and Actual Values")

pre # to display only upto 3 decimal places

# %%
# Set CSS properties for th elements in dataframe
th_props = [
    ('background', 'rgb(12, 64, 90)'),
    ('background', 'linear-gradient(0deg, rgba(21, 112, 157) 0%, rgba(12, 64, 90) 120%)'),
    ('padding', '5px'),
    ('font-family', 'arial'),
    ('font-size', '100%'),
    ('color', 'white'),
    ('border', '0.5px') ,
    ('border', 'solid #0c405a'),
    ('text-align', 'center')
  ]

# Set CSS properties for td elements in dataframe
td_props = [
#     ('background', 'rgb(232, 247, 252)'),
    ('border', '0.5px'),
    ('border','solid #0c405a')    
  ]

# Set table styles
styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props),
  dict(selector="caption", props=[("text-align", "left"),("font-size", "120%"),("color", 'black')])
  ]

def color_func(value):           # setting different color for F1 or RMSE column
    if value.name in ['Weighted F1','RMSE']:
        color= '#f7f7ba'
    else:
#         print(value)
        color= '#e8f7fc'
    return ['background-color: %s' %color]*len(value)


MC = pd.read_csv('MC.csv')
if 'Weighted F1' in MC.columns:          # for setting caption
    cap='This table is sorted by F1 Score(Weighted F1), higher the better'
else:
    cap ='This table is sorted by Root Mean Squared Error(RMSE), lower the better'
MC.index = np.arange(1,len(MC)+1)       # adjusting index
if 'Weighted F1' in MC.columns:        #for setting decimal places
    mc= MC.style.set_table_styles(styles).set_caption(cap).apply(color_func, axis=0).set_precision(3)
else:
    mc= MC.style.set_table_styles(styles).set_caption(cap).apply(color_func, axis=0).set_precision(2)
    
mc

# %%
# joblib.load('XT').min().min()

# %%
# joblib.load('Xt').min().min()

# %%
# joblib.load('XT').max().max()

# %%
# joblib.load('Xt').max().max()

# %%
# joblib.load('YT').max()

# %%
# joblib.load('Yt').max()

# %%
# joblib.load('YT').min()

# %%
# joblib.load('Yt').min()

# %%
# import pandas as pd
# # df = pd.read_csv('SheetSheetSheet.csv')
