# %% [markdown]
# # Proton Scoring/Future Prediction

# %% [markdown]
# ### Dependencies

# %%
# !pip3 install swifter
# !pip3 install xgboost
# !pip3 install tqdm
# !pip3 install category_encoders
# !pip3 install joblib
# !pip3 install scikit-plot
# !pip3 install catboost
# !pip3 install RegscorePy
# !pip3 install -U spacy
# !pip3 install gensim
# !pip3 install xlrd
# !pip3 install lightgbm
# !pip3 install hyperopt
# !pip3 install holidays
# !pip3 install textblob
# !python -m spacy download en_core_web_sm
# Download en_core_web_sm for text analytics

# %% [markdown]
# ## Imports

# %%
from userInputs import importFile,dataHandler,duplicateHandler
from engineerings import *
from all_other_functions import getDF
from score import *
import joblib
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Main Function

# %%
def main():
    # IMPORT MODEL    
    model_info = joblib.load('model_info')
    
    # IMPORT SCORING FILE
    dfPath = input('Enter the Scoring File path : ').strip()
    df,_ = importFile(None,None,dfPath)
    df = df.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
    df = duplicateHandler(df)
    df,update = dataHandler(df,None) # If first few rows contains unnecessary info
    df = duplicateHandler(df) #calling again if dataHandler drops columns
    print(df.columns)

    # Filter DataFrame based on columns
    df = getDF(df,model_info)
    if not isinstance(df,pd.DataFrame): # If Columns don't match, 
        print('QUITTING!') # QUIT by printing what columns don't match/are not found
        return 0
    
    # Numeric Engineering of DATA
    print('\n#### Entering Numeric Engineering ####\n')
    df = numeric_engineering(df)
    
    # SCORE
    outputFile = score(df,model_info)    
    
    print('Done!')
    return 0

if __name__ == '__main__':
    main()
# Out:
# Enter the Scoring File path : datasets/amlcopy.csv
# #### RUNNING WAIT ####
# extension is csv
# We have a csv file
# This file has 323 columns and 28240 rows
# Index(['CONSTITUENTSYSTEMID', 'ASKAMOUNT1', 'ASKAMOUNT2', 'ASKAMOUNT3',
#        'ASKAMOUNT4', 'ASKAMOUNT5', 'ASKAMOUNT6', 'ASKAMOUNT7', 'ASKAMOUNT8',
#        'ASKAMOUNT9',
#        ...
#        'PDL_DEC_6025', 'CDOLB8', 'CRECL9', 'CTRNA9', 'CDOLL10', 'CRECL10',
#        'CRECL12', 'CTRNA12', 'CDOLL10_AVGGIFT', 'CDOLL8_AVGGIFT'],
#       dtype='object', length=323)
# Columns Match!
#
# #### Entering Numeric Engineering ####
#
# 		 stripping spaces, symbols, and lower casing all entries
# done ...
# 		 Replacing empty and invalid strings
# done ...
# 		 Replacing commas if present in Currencies
# done ...
# 		 Finding Numeric Columns
# done ...
# 		   CONSTITUENTSYSTEMID is of type object
# 		   ASKAMOUNT1 is of type float64
# 		   ASKAMOUNT2 is of type float64
# 		   ASKAMOUNT3 is of type float64
# 		   ASKAMOUNT4 is of type float64
# 		   ASKAMOUNT5 is of type float64
# 		   ASKAMOUNT6 is of type float64
# 		   ASKAMOUNT7 is of type float64
# 		   ASKAMOUNT8 is of type float64
# 		   ASKAMOUNT9 is of type float64
# 		   ASKAMOUNT10 is of type float64
# 		   TARGET_RESPONSE_AMOUNT is of type float64
# 		   WEB_TOT_GIFTS is of type float64
# 		   WEB_TOT_REV is of type float64
# 		   WEB_REV_1YR is of type float64
# 		   WEB_NUM_GFTS_DEC is of type float64
# 		   WEB_FIRST_CAMPAIGN is of type object
# 		   WEB_FIRST_PMT_AMT is of type object
# 		   WEB_LAST_PMT_AMT is of type object
# 		   WEB_DYN_MSG_CAMPAIGN is of type object
# 		   WEB_DYN_MSG_PYMT_AMT is of type float64
# 		   WEB_TENURE is of type float64
# 		   WEB_SINCE_LAST_GIFT is of type float64
# 		   WEB_YEARS_CONSEC_GIVING is of type object
# 		   WEB_TOTAL_NUM_I is of type int64
# 		   CMP_B_CARD_AVG_RECENCY is of type float64
# 		   TSP_INDVEXACTAGEPRSN1 is of type float64
# 		   TSP_NICHES4 is of type object
# 		   TSP_ADVTARGINC3 is of type object
# 		   TSP_HOMESALEPRICEIN1KDLRS is of type float64
# 		   TSP_AVAILHOMEEQUITYAMTIN1KDLRS is of type float64
# 		   TSP_1STMORTGAMTIN1KDLRS is of type float64
# 		   TSP_2NDMORTGAMTIN1KDLRS is of type float64
# 		   TSP_MT_INSURANCESWITCHER is of type float64
# 		   TSP_MT_SATELLITEBUNDLE is of type float64
# 		   TSP_MT_ENVDONORS is of type float64
# 		   TSP_POP_DENSITY is of type float64
# 		   TSP_POP_PCT1824 is of type float64
# 		   TSP_HH_PCT2PLUSPRSNHHNONFAM is of type float64
# 		   TSP_WRK_PCTTRANSTOWRKBICYCLE is of type float64
# 		   TSP_HU_PCT1UNITDETACHED is of type float64
# 		   TSP_OOHU_PCTVAL150K200K is of type float64
# 		   TSP_OOHU_PCTVAL300K400K is of type float64
# 		   prob_of_being_dead is of type float64
# 		   DEADCAT is of type object
# 		   CHECK_1YR is of type float64
# 		   CHECK_REV_1YR is of type float64
# 		   CREDIT_CARD_ALL_REV_TOT is of type float64
# 		   CHECK_TOT is of type float64
# 		   CHECK_REV_TOT is of type float64
# 		   DRM_TOT_GIFTS is of type float64
# 		   DRM_TOT_REV is of type float64
# 		   DRM_MAX_AMT is of type float64
# 		   DRM_REV_1YR is of type float64
# 		   DRM_REV_2YR is of type float64
# 		   DRM_GIFTS_1YR is of type float64
# 		   DRM_GIFTS_2YR is of type float64
# 		   DRM_GIFTS_6MO is of type float64
# 		   DRM_NUM_GFTS_JAN is of type float64
# 		   DRM_NUM_GFTS_JUL is of type float64
# 		   DRM_NUM_GFTS_DEC is of type float64
# 		   DRM_FIRST_CAMPAIGN is of type object
# 		   DRM_FIRST_PMT_AMT is of type object
# 		   DRM_LAST_CAMPAIGN is of type object
# 		   DRM_LAST_PMT_AMT is of type object
# 		   DRM_DYN_MSG_CAMPAIGN is of type object
# 		   DRM_DYN_MSG_PYMT_AMT is of type float64
# 		   DRM_AVG_RECENCY is of type float64
# 		   DRM_YEARS_CONSEC_GIVING is of type float64
# 		   DRM_TOTAL_NUM_I is of type float64
# 		   DRM_I_1MO is of type float64
# 		   DRM_I_2MO is of type float64
# 		   DRM_I_3MO is of type float64
# 		   DRM_I_4MO is of type float64
# 		   DRM_I_5MO is of type float64
# 		   DRM_I_6MO is of type float64
# 		   DRM_I_1YR_PRIOR is of type float64
# 		   CC_MAX_AMT is of type float64
# 		   CC_REV_5MO is of type float64
# 		   CC_YEARS_CONSEC_GIVING is of type object
# 		   ALL_TOT_GIFTS_ADJ is of type float64
# 		   ALL_TOT_REV_ADJ is of type float64
# 		   ALL_MAX_AMT_ADJ is of type float64
# 		   ALL_REV_1YR_ADJ is of type float64
# 		   ALL_REV_2YR_ADJ is of type float64
# 		   ALL_AVG_RECENCY_ADJ is of type float64
# 		   ALL_FIRST_AMT_ADJ is of type float64
# 		   ALL_LAST_AMT_ADJ is of type float64
# 		   ALL_DYN_MSG_PYMT_AMT_ADJ is of type float64
# 		   CATALOG_TOT_REV is of type float64
# 		   CATALOG_NUM_GFTS_DEC is of type float64
# 		   CATALOG_GIFT_YEARS is of type float64
# 		   CATALOG_FIRST_PAY_MTHD is of type object
# 		   CATALOG_SINCE_LAST_GIFT is of type float64
# 		   CATALOG_AVG_RECENCY is of type float64
# 		   CATALOG_YEARS_CONSEC_GIVING is of type float64
# 		   CMP_A_FIRST_DATE is of type object
# 		   CMP_A_LAST_DATE is of type object
# 		   CMP_A_TOT_GIFTS is of type float64
# 		   CMP_A_TOT_REV is of type float64
# 		   CMP_A_MAX_AMT is of type float64
# 		   CMP_A_GIFT_LAST_MONTH is of type float64
# 		   CMP_A_REV_1YR is of type float64
# 		   CMP_A_REV_2YR is of type float64
# 		   CMP_A_REV_3YR is of type float64
# 		   CMP_A_REV_4YR is of type float64
# 		   CMP_A_REV_5YR is of type float64
# 		   CMP_A_GIFTS_1YR is of type float64
# 		   CMP_A_GIFTS_2YR is of type float64
# 		   CMP_A_GIFTS_3YR is of type float64
# 		   CMP_A_GIFTS_4YR is of type float64
# 		   CMP_A_GIFTS_5YR is of type float64
# 		   CMP_A_REV_1MO is of type float64
# 		   CMP_A_REV_2MO is of type float64
# 		   CMP_A_REV_3MO is of type float64
# 		   CMP_A_REV_4MO is of type float64
# 		   CMP_A_REV_5MO is of type float64
# 		   CMP_A_REV_6MO is of type float64
# 		   CMP_A_GIFTS_1MO is of type float64
# 		   CMP_A_GIFTS_2MO is of type float64
# 		   CMP_A_GIFTS_3MO is of type float64
# 		   CMP_A_GIFTS_4MO is of type float64
# 		   CMP_A_GIFTS_5MO is of type float64
# 		   CMP_A_GIFTS_6MO is of type float64
# 		   CMP_A_NUM_GFTS_JAN is of type float64
# 		   CMP_A_NUM_GFTS_FEB is of type float64
# 		   CMP_A_NUM_GFTS_MAR is of type float64
# 		   CMP_A_NUM_GFTS_APR is of type float64
# 		   CMP_A_NUM_GFTS_MAY is of type float64
# 		   CMP_A_NUM_GFTS_JUN is of type float64
# 		   CMP_A_NUM_GFTS_JUL is of type float64
# 		   CMP_A_NUM_GFTS_AUG is of type float64
# 		   CMP_A_NUM_GFTS_SEP is of type float64
# 		   CMP_A_NUM_GFTS_OCT is of type float64
# 		   CMP_A_NUM_GFTS_NOV is of type float64
# 		   CMP_A_NUM_GFTS_DEC is of type float64
# 		   CMP_A_GIFT_YEARS is of type float64
# 		   CMP_A_FIRST_ACTIVITY is of type object
# 		   CMP_A_FIRST_CAMPAIGN is of type object
# 		   CMP_A_FIRST_PAY_MTHD is of type object
# 		   CMP_A_FIRST_PMT_AMT is of type object
# 		   CMP_A_LAST_ACTIVITY is of type object
# 		   CMP_A_LAST_CAMPAIGN is of type object
# 		   CMP_A_LAST_PAY_MTHD is of type object
# 		   CMP_A_LAST_PMT_AMT is of type object
# 		   CMP_A_DYN_MSG_DATE is of type object
# 		   CMP_A_DYN_MSG_ACTIVITY is of type object
# 		   CMP_A_DYN_MSG_CAMPAIGN is of type object
# 		   CMP_A_DYN_MSG_PAY_MTHD is of type object
# 		   CMP_A_DYN_MSG_PYMT_AMT is of type float64
# 		   CMP_A_TENURE is of type float64
# 		   CMP_A_SINCE_LAST_GIFT is of type float64
# 		   CMP_A_AVG_RECENCY is of type float64
# 		   CMP_A_YEARS_CONSEC_GIVING is of type float64
# 		   CMP_B_TOT_GIFTS is of type float64
# 		   CMP_B_NUM_GFTS_JAN is of type float64
# 		   CMP_B_NUM_GFTS_OCT is of type float64
# 		   CMP_B_LAST_PAY_MTHD is of type object
# 		   CMP_B_AVG_RECENCY is of type float64
# 		   CMP_B_YEARS_CONSEC_GIVING is of type float64
# 		   CMP_L_DYN_MSG_PAY_MTHD is of type object
# 		   CMP_A_TOTAL_NUM_I is of type float64
# 		   CMP_A_FIRST_I_DATE is of type object
# 		   CMP_A_LAST_I_DATE is of type object
# 		   CMP_A_I_3MO_PRIOR is of type float64
# 		   CMP_A_I_6MO_PRIOR is of type float64
# 		   CMP_A_I_1YR_PRIOR is of type float64
# 		   CMP_B_TOTAL_NUM_I is of type float64
# 		   CMP_B_I_3MO_PRIOR is of type float64
# 		   CMP_B_I_6MO_PRIOR is of type float64
# 		   CMP_B_I_1YR_PRIOR is of type float64
# 		   CMP_L_TOTAL_NUM_I is of type float64
# 		   CMP_R_TOTAL_NUM_I is of type float64
# 		   CMP_R_I_3MO_PRIOR is of type float64
# 		   CMP_R_I_6MO_PRIOR is of type float64
# 		   CMP_R_I_1YR_PRIOR is of type float64
# 		   ALL_TOT_GIFTS is of type float64
# 		   ALL_TOT_REV is of type float64
# 		   ALL_MAX_AMT is of type float64
# 		   ALL_REV_1YR is of type float64
# 		   ALL_REV_3YR is of type float64
# 		   ALL_REV_5YR is of type float64
# 		   ALL_GIFTS_1YR is of type float64
# 		   ALL_GIFTS_2YR is of type float64
# 		   ALL_GIFTS_3YR is of type float64
# 		   ALL_GIFTS_4YR is of type float64
# 		   ALL_GIFTS_5YR is of type float64
# 		   ALL_REV_2MO is of type float64
# 		   ALL_REV_3MO is of type float64
# 		   ALL_REV_4MO is of type float64
# 		   ALL_REV_6MO is of type float64
# 		   ALL_GIFTS_2MO is of type float64
# 		   ALL_GIFTS_4MO is of type float64
# 		   ALL_GIFTS_5MO is of type float64
# 		   ALL_GIFTS_6MO is of type float64
# 		   ALL_NUM_GFTS_JAN is of type float64
# 		   ALL_NUM_GFTS_FEB is of type float64
# 		   ALL_NUM_GFTS_JUN is of type float64
# 		   ALL_NUM_GFTS_SEP is of type float64
# 		   ALL_NUM_GFTS_DEC is of type float64
# 		   ALL_GIFT_YEARS is of type float64
# 		   ALL_FIRST_CAMPAIGN is of type object
# 		   ALL_FIRST_PMT_AMT is of type object
# 		   ALL_LAST_CAMPAIGN is of type object
# 		   ALL_LAST_PMT_AMT is of type object
# 		   ALL_DYN_MSG_CAMPAIGN is of type object
# 		   ALL_DYN_MSG_PYMT_AMT is of type float64
# 		   ALL_SINCE_LAST_GIFT is of type float64
# 		   ALL_AVG_RECENCY is of type float64
# 		   ALL_YEARS_CONSEC_GIVING is of type float64
# 		   NUM_ADDRESS_CHANGES is of type int64
# 		   EPSILONKEY is of type object
# 		   ODOLL1 is of type float64
# 		   MTRNL70 is of type float64
# 		   MTRNA70 is of type float64
# 		   MDOLB70 is of type float64
# 		   MTRNB70 is of type float64
# 		   MTDLT25A70 is of type float64
# 		   MTD25_49A70 is of type float64
# 		   MTD1LT25B70 is of type float64
# 		   MTD_JAN_6070 is of type float64
# 		   MTD_MAY_6070 is of type float64
# 		   MTD_JUN_6070 is of type float64
# 		   MTD_DEC_6070 is of type float64
# 		   MDL_JAN_6070 is of type float64
# 		   MDL_MAY_6070 is of type float64
# 		   MDL_JUN_6070 is of type float64
# 		   MDL_AUG_6070 is of type float64
# 		   MDL_DEC_6070 is of type float64
# 		   MRECL73 is of type float64
# 		   MTRNA73 is of type float64
# 		   MDOLA73 is of type float64
# 		   MTDLT25A73 is of type float64
# 		   MTD25_49B73 is of type float64
# 		   MTD_JAN_6073 is of type float64
# 		   MTD_DEC_6073 is of type float64
# 		   MDL_JAN_6073 is of type float64
# 		   MDL_SEP_6073 is of type float64
# 		   MDL_DEC_6073 is of type float64
# 		   MRECL76 is of type float64
# 		   MRECL78 is of type float64
# 		   PRECL3 is of type float64
# 		   PRECL8 is of type float64
# 		   PRECL10 is of type float64
# 		   PRECL15 is of type float64
# 		   PRECL18 is of type float64
# 		   PDOLL22 is of type float64
# 		   PRECL24 is of type float64
# 		   PTRNA24 is of type float64
# 		   PTD_JAN_6024 is of type float64
# 		   PTD_DEC_6024 is of type float64
# 		   PDL_JAN_6024 is of type float64
# 		   PDL_FEB_6024 is of type float64
# 		   PDL_DEC_6024 is of type float64
# 		   PRECL25 is of type float64
# 		   SDOLL21 is of type float64
# 		   CDOLL4 is of type float64
# 		   CRECL4 is of type float64
# 		   CTRNA5 is of type float64
# 		   CTRNA6 is of type float64
# 		   CDOLB6 is of type float64
# 		   CTRNA7 is of type float64
# 		   CDOLA7_RATIOCAT is of type object
# 		   ODOLA1_RATIOCAT is of type object
# 		   PDOLA15_RATIOCAT is of type object
# 		   PDOLA24_RATIOCAT is of type object
# 		   OTRNA1_RATIOCAT is of type object
# 		   CDOLB4_AVGGIFT is of type object
# 		   CDOLL4_AVGGIFT is of type object
# 		   CDOLB5_AVGGIFT is of type object
# 		   CDOLL5_AVGGIFT is of type object
# 		   CDOLA6_AVGGIFT is of type object
# 		   CDOLL6_AVGGIFT is of type object
# 		   CDOLB6_AVGGIFT is of type object
# 		   CDOLA7_AVGGIFT is of type object
# 		   CDOLB7_AVGGIFT is of type object
# 		   MDOLA70_AVGGIFT is of type object
# 		   MDOLL71_AVGGIFT is of type object
# 		   MDOLB73_AVGGIFT is of type object
# 		   MDOLL73_AVGGIFT is of type object
# 		   MDOLL75_AVGGIFT is of type object
# 		   MDOLA76_AVGGIFT is of type object
# 		   MDOLL76_AVGGIFT is of type object
# 		   MDOLL77_AVGGIFT is of type object
# 		   MDOLL78_AVGGIFT is of type object
# 		   ODOLL1_AVGGIFT is of type object
# 		   ODOLB1_AVGGIFT is of type object
# 		   ODOLA1_AVGGIFT is of type object
# 		   PDOLA11_AVGGIFT is of type object
# 		   PDOLB12_AVGGIFT is of type object
# 		   PDOLL15_AVGGIFT is of type object
# 		   PDOLL16_AVGGIFT is of type object
# 		   PDOLB17_AVGGIFT is of type object
# 		   PDOLL20_AVGGIFT is of type object
# 		   PDOLA20_AVGGIFT is of type object
# 		   PDOLL22_AVGGIFT is of type object
# 		   PDOLA23_AVGGIFT is of type object
# 		   PDOLL24_AVGGIFT is of type object
# 		   PDOLB24_AVGGIFT is of type object
# 		   PDOLA24_AVGGIFT is of type object
# 		   PDOLB25_AVGGIFT is of type object
# 		   PDOLL5_AVGGIFT is of type object
# 		   PDOLA5_AVGGIFT is of type object
# 		   PDOLA6_AVGGIFT is of type object
# 		   PDOLB9_AVGGIFT is of type object
# 		   MTRNL70_PCTNFP is of type float64
# 		   PTRNA24_PCTALL is of type float64
# 		   PTRNL24_PCTALL is of type float64
# 		   MDL_DEC_6075 is of type float64
# 		   MTD_DEC_6076 is of type float64
# 		   PDL_NOV_601 is of type float64
# 		   PDL_JAN_6025 is of type float64
# 		   PDL_DEC_6025 is of type float64
# 		   CDOLB8 is of type float64
# 		   CRECL9 is of type float64
# 		   CTRNA9 is of type float64
# 		   CDOLL10 is of type float64
# 		   CRECL10 is of type float64
# 		   CRECL12 is of type float64
# 		   CTRNA12 is of type float64
# 		   CDOLL10_AVGGIFT is of type object
# 		   CDOLL8_AVGGIFT is of type object
# Numeric Engineering time taken: 4.846196889877319
#
#
#
# 	 #### VALIDATION AND SCORING ZONE ####
# Target Unique values and count
#  Series([], dtype: int64)
#  Unique values
#  0
# Value of Key from Training is:  CONSTITUENTSYSTEMID
# Total no. of null values present in the Key:  0
# NUll values after removal are:  0
# Runnning Date Engineering on validation dataset
#
# 	 Entering Date Engineering
#
# Printing Missing % of date columns
#                     Missing in %
# CMP_A_LAST_I_DATE          28.68
# CMP_A_FIRST_I_DATE         28.68
# 	 #### RUNNING WAIT ####
#
# Visualizing Coloumns Generated
#  {'CMP_A_FIRST_I_DATE': ['CMP_A_FIRST_I_DATE_month', 'CMP_A_FIRST_I_DATE_year', 'CMP_A_FIRST_I_DATE-today', 'CMP_A_FIRST_I_DATE_nearestHoliday'], 'CMP_A_LAST_I_DATE': ['CMP_A_LAST_I_DATE_month', 'CMP_A_LAST_I_DATE_year', 'CMP_A_LAST_I_DATE-today', 'CMP_A_LAST_I_DATE_nearestHoliday']}
#
# The Following columns were generated to get days between dates of two seperate date columns
#  ['CMP_A_FIRST_I_DATE-CMP_A_LAST_I_DATE']
#
# Date Engineering Time Taken : 2.028787136077881
#
# 	 #### DONE ####
# Pandas Apply:   0%|          | 0/138 [00:00<?, ?it/s]
# Shape after Pearsons Correlation (28240, 110)
# num_df - (28240, 110)
# disc_df - (28240, 62)
# DATE_DF - (28240, 9)
# TEXT_DF - (0, 0)
# LAT_LONG_DF - (0, 0)
# EMAIL_DF - (0, 0)
# URL_DF - (0, 0)
# Applying Target Encoding...
# Target Encoding completed
# Applying Scaling and Transformations on Validation Set...
# Scaling and Transformation completed
#
# This is final shape of X_test : (28240, 110)
#
#  #### PRINTING THE LIST OF COLUMNS AND ITS TYPES THAT ENTER THE MODEL TRAINING ####
# #### PRINTING X_test ####
# Index(['WEB_TOTAL_NUM_I', 'TSP_INDVEXACTAGEPRSN1', 'TSP_MT_INSURANCESWITCHER',
#        'TSP_MT_SATELLITEBUNDLE', 'TSP_MT_ENVDONORS', 'TSP_POP_DENSITY',
#        'TSP_POP_PCT1824', 'TSP_HH_PCT2PLUSPRSNHHNONFAM',
#        'TSP_WRK_PCTTRANSTOWRKBICYCLE', 'TSP_HU_PCT1UNITDETACHED',
#        ...
#        'PDOLA15_RATIOCAT', 'WEB_FIRST_PMT_AMT', 'CDOLB5_AVGGIFT',
#        'DRM_LAST_CAMPAIGN', 'CDOLB7_AVGGIFT', 'ALL_LAST_PMT_AMT',
#        'WEB_LAST_PMT_AMT', 'DRM_LAST_PMT_AMT', 'CDOLA7_RATIOCAT',
#        'CDOLL5_AVGGIFT'],
#       dtype='object', length=110)
# WEB_TOTAL_NUM_I             float64
# TSP_INDVEXACTAGEPRSN1       float64
# TSP_MT_INSURANCESWITCHER    float64
# TSP_MT_SATELLITEBUNDLE      float64
# TSP_MT_ENVDONORS            float64
#                              ...
# ALL_LAST_PMT_AMT            float64
# WEB_LAST_PMT_AMT            float64
# DRM_LAST_PMT_AMT            float64
# CDOLA7_RATIOCAT             float64
# CDOLL5_AVGGIFT              float64
# Length: 110, dtype: object
#
#
#     WEB_TOTAL_NUM_I  TSP_INDVEXACTAGEPRSN1  TSP_MT_INSURANCESWITCHER  \
# 0          0.803981               1.000000                  1.000000
# 1          0.000000               1.000000                  0.250881
# 2          0.000000               1.000000                  0.250881
# 3          0.000000               0.403638                  0.472375
# 4          0.000000               0.502646                  0.499451
# 5          0.000000               1.000000                  0.054160
# 6          0.000000               1.000000                  0.054160
# 7          0.000000               1.000000                  0.054160
# 8          0.000000               1.000000                  0.054160
# 9          0.000000               0.276684                  0.668116
# 10         0.000000               0.276684                  0.668116
# 11         0.000000               0.830593                  1.000000
# 12         0.000000               0.830593                  1.000000
# 13         0.000000               0.864260                  0.697749
# 14         0.000000               0.864260                  0.697749
# 15         0.025802               0.435724                  0.000000
# 16         0.025802               0.435724                  0.000000
# 17         0.025802               0.435724                  0.000000
# 18         0.000000               0.898035                  0.916827
# 19         0.988459               0.000000                  0.933255
#
#     TSP_MT_SATELLITEBUNDLE  TSP_MT_ENVDONORS  TSP_POP_DENSITY  \
# 0                 0.251478          0.675124         0.424604
# 1                 0.856632          1.000000         0.823308
# 2                 0.856632          1.000000         0.823308
# 3                 0.475364          0.000000         0.406859
# 4                 0.551653          0.581169         0.742883
# 5                 0.187988          0.000000         0.345382
# 6                 0.187988          0.000000         0.345382
# 7                 0.187988          0.000000         0.345382
# 8                 0.187988          0.000000         0.345382
# 9                 0.311689          0.103417         0.349941
# 10                0.311689          0.103417         0.349941
# 11                0.000000          0.035772         0.573261
# 12                0.000000          0.035772         0.573261
# 13                0.271897          0.070221         1.000000
# 14                0.271897          0.070221         1.000000
# 15                0.097663          0.000000         0.027764
# 16                0.097663          0.000000         0.027764
# 17                0.097663          0.000000         0.027764
# 18                0.572529          0.035772         1.000000
# 19                0.675922          0.401628         0.121312
#
#     TSP_POP_PCT1824  TSP_HH_PCT2PLUSPRSNHHNONFAM  \
# 0          0.316817                     0.195238
# 1          0.000000                     0.000000
# 2          0.000000                     0.000000
# 3          0.316817                     0.626482
# 4          0.535710                     0.584455
# 5          0.000000                     0.360412
# 6          0.000000                     0.360412
# 7          0.000000                     0.360412
# 8          0.000000                     0.360412
# 9          0.000000                     0.000000
# 10         0.000000                     0.000000
# 11         0.000000                     0.195238
# 12         0.000000                     0.195238
# 13         0.000000                     0.195238
# 14         0.000000                     0.195238
# 15         0.316817                     0.502523
# 16         0.316817                     0.502523
# 17         0.316817                     0.502523
# 18         0.481982                     1.000000
# 19         1.000000                     0.000000
#
#     TSP_WRK_PCTTRANSTOWRKBICYCLE  TSP_HU_PCT1UNITDETACHED  ...  \
# 0                       0.346048                 0.869740  ...
# 1                       0.000000                 0.000000  ...
# 2                       0.000000                 0.000000  ...
# 3                       0.346048                 0.973202  ...
# 4                       0.644269                 0.471841  ...
# 5                       0.895194                 0.334397  ...
# 6                       0.895194                 0.334397  ...
# 7                       0.895194                 0.334397  ...
# 8                       0.895194                 0.334397  ...
# 9                       0.000000                 0.000000  ...
# 10                      0.000000                 0.000000  ...
# 11                      0.346048                 0.702738  ...
# 12                      0.346048                 0.702738  ...
# 13                      0.761614                 0.000000  ...
# 14                      0.761614                 0.000000  ...
# 15                      0.346048                 0.615110  ...
# 16                      0.346048                 0.615110  ...
# 17                      0.346048                 0.615110  ...
# 18                      0.000000                 0.100372  ...
# 19                      0.346048                 1.000000  ...
#
#     PDOLA15_RATIOCAT  WEB_FIRST_PMT_AMT  CDOLB5_AVGGIFT  DRM_LAST_CAMPAIGN  \
# 0           0.588914           0.266469        0.557941           0.418230
# 1           1.000000           0.266469        0.557941           0.319067
# 2           1.000000           0.266469        0.557941           0.319067
# 3           1.000000           0.266469        0.557941           0.319067
# 4           1.000000           0.266469        0.118890           0.305224
# 5           1.000000           0.266469        0.557941           0.346476
# 6           1.000000           0.266469        0.557941           0.346476
# 7           1.000000           0.266469        0.557941           0.346476
# 8           1.000000           0.266469        0.557941           0.346476
# 9           1.000000           0.266469        0.557941           0.319067
# 10          1.000000           0.266469        0.557941           0.319067
# 11          0.588914           0.266469        0.557941           0.369846
# 12          0.588914           0.266469        0.557941           0.369846
# 13          0.588914           0.266469        0.557941           0.388985
# 14          0.588914           0.266469        0.557941           0.388985
# 15          1.000000           0.266469        0.557941           0.305224
# 16          1.000000           0.266469        0.557941           0.305224
# 17          1.000000           0.266469        0.557941           0.305224
# 18          1.000000           0.266469        0.482410           0.369846
# 19          0.588914           0.011596        0.557941           0.319067
#
#     CDOLB7_AVGGIFT  ALL_LAST_PMT_AMT  WEB_LAST_PMT_AMT  DRM_LAST_PMT_AMT  \
# 0         0.576437          1.000000          0.315185          1.000000
# 1         0.576437          0.404712          0.315185          0.092765
# 2         0.576437          0.404712          0.315185          0.092765
# 3         0.576437          0.000000          0.315185          0.092765
# 4         0.149816          0.000000          0.315185          0.000000
# 5         0.576437          0.439067          0.315185          0.405118
# 6         0.576437          0.439067          0.315185          0.405118
# 7         0.576437          0.439067          0.315185          0.405118
# 8         0.576437          0.439067          0.315185          0.405118
# 9         0.576437          0.413232          0.315185          0.092765
# 10        0.576437          0.413232          0.315185          0.092765
# 11        0.576437          0.407701          0.315185          0.551021
# 12        0.576437          0.407701          0.315185          0.551021
# 13        0.485588          0.413232          0.315185          0.481162
# 14        0.485588          0.413232          0.315185          0.481162
# 15        0.576437          0.439067          0.315185          0.405118
# 16        0.576437          0.439067          0.315185          0.405118
# 17        0.576437          0.439067          0.315185          0.405118
# 18        0.791649          0.413232          0.315185          0.481162
# 19        0.576437          0.000000          0.112318          0.092765
#
#     CDOLA7_RATIOCAT  CDOLL5_AVGGIFT
# 0           0.89467         0.53005
# 1           0.00000         0.53005
# 2           0.00000         0.53005
# 3           0.89467         0.53005
# 4           0.89467         0.53005
# 5           0.89467         0.53005
# 6           0.89467         0.53005
# 7           0.89467         0.53005
# 8           0.89467         0.53005
# 9           0.00000         0.33197
# 10          0.00000         0.33197
# 11          0.00000         0.53005
# 12          0.00000         0.53005
# 13          0.00000         0.53005
# 14          0.00000         0.53005
# 15          0.89467         0.53005
# 16          0.89467         0.53005
# 17          0.89467         0.53005
# 18          0.00000         0.53005
# 19          0.00000         0.53005
#
# [20 rows x 110 columns]
# 0 is present in 60.131% of the Scoring File
# 1 is present in 39.869% of the Scoring File
#
#
# File Saved as score.csv
#
# Code executed Successfully
#
# ############# END ###########
# Done!

# %% [markdown]
# ## Preview of Predictions

# %%
# joblib.load('model_info')

# %%
pd.read_csv('score.csv').head(20)
# Out:
#                                     S.No  Predicted Values  \
# 0   00000142-1B60-44B2-8E0C-2482C9A7B50E                 0
# 1   0000027E-13B0-4F6F-8419-3FC02C702BF8                 0
# 2   0000027E-13B0-4F6F-8419-3FC02C702BF8                 0
# 3   00000897-C016-4D02-9393-35F93D7EB431                 0
# 4   00000A9B-C1E8-4A64-99C9-59199271DD04                 0
# 5   0000138B-08A0-45D7-A3FE-F741A9F40AC8                 1
# 6   0000138B-08A0-45D7-A3FE-F741A9F40AC8                 1
# 7   0000138B-08A0-45D7-A3FE-F741A9F40AC8                 1
# 8   0000138B-08A0-45D7-A3FE-F741A9F40AC8                 1
# 9   00003C14-12B4-4F02-B683-65F60181D4DA                 0
# 10  00003C14-12B4-4F02-B683-65F60181D4DA                 0
# 11  00003D13-3426-430E-8C05-D264E8C9FB26                 0
# 12  00003D13-3426-430E-8C05-D264E8C9FB26                 0
# 13  00003FCB-06A9-4FC5-A839-E88AA753DAA8                 1
# 14  00003FCB-06A9-4FC5-A839-E88AA753DAA8                 1
# 15  000041B8-AAFB-4C3E-9D0B-728C9A8AC94E                 1
# 16  000041B8-AAFB-4C3E-9D0B-728C9A8AC94E                 1
# 17  000041B8-AAFB-4C3E-9D0B-728C9A8AC94E                 1
# 18  0000463D-D3F2-4E38-99B4-F432BFD9B0A2                 1
# 19  00007943-BCF2-4F5F-9E95-993AE8F186FF                 0
#
#     Class 0 Probabilities  Class 1 Probabilities
# 0                   0.510                  0.490
# 1                   0.625                  0.375
# 2                   0.640                  0.360
# 3                   0.605                  0.395
# 4                   0.694                  0.306
# 5                   0.416                  0.584
# 6                   0.370                  0.630
# 7                   0.446                  0.554
# 8                   0.432                  0.568
# 9                   0.611                  0.389
# 10                  0.613                  0.387
# 11                  0.520                  0.480
# 12                  0.516                  0.484
# 13                  0.358                  0.642
# 14                  0.377                  0.623
# 15                  0.303                  0.697
# 16                  0.307                  0.693
# 17                  0.434                  0.566
# 18                  0.413                  0.587
# 19                  0.706                  0.294
