# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel('memcopy.xlsx')

# %%
df.shape
# Out:
# (367014, 14)

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.dropna(axis=0,how='all').isnull())
# Out:
# <AxesSubplot:>
